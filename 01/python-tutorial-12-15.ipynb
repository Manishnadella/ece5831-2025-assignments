# %% [markdown]
# ## Section 12

# %%
with open('text_for_llm-1.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# Art describes a diverse range of cultural activity centered around works utilizing creative or imaginative talents, which are expected to evoke a worthwhile experience,[1] generally through an expression of emotional power, conceptual ideas, technical proficiency, and/or beauty. There is no generally agreed definition of what constitutes art, and its interpretation has varied greatly throughout history and across cultures. In the Western tradition, the three classical branches of visual art are painting, sculpture, and architecture. Theatre, dance, and other performing arts, as well as literature, music, film and other media such as interactive media, are included in a broader definition of "the arts". Until the 17th century, art referred to any skill or mastery and was not differentiated from crafts or sciences. In modern usage after the 17th century, where aesthetic considerations are paramount, the fine arts are separated and distinguished from acquired skills in general, such as the decorative or applied arts. The nature of art and related concepts, such as creativity and interpretation, are explored in a branch of philosophy known as aesthetics. The resulting artworks are studied in the professional fields of art criticism and the history of art.
#
# A film, also known as a movie or motion picture, is a work of visual art that simulates experiences and otherwise communicates ideas, stories, perceptions, emotions, or atmosphere through the use of moving images that are generally, since the 1930s, synchronized with sound and (less commonly) other sensory stimulations.[1] The word "cinema" is borrowed from the French cinéma, an abbreviation of cinématographe (term coined by the Lumière brothers in the 1890s), from Ancient Greek meaning "recording movement". The word is today usually used to refer to either a purpose-built venue for screening films, known as a movie theater in the US; the film industry; the overall art form of specifically just filmmaking. The moving images of a film are created by photographing actual scenes with a motion-picture camera, by photographing drawings or miniature models using traditional animation techniques, by means of CGI and computer animation, or by a combination of some or all of these techniques, and other visual effects. Before the introduction of digital production, a series of still images were recorded on a strip of chemically sensitized celluloid (photographic film stock), usually at a rate of 24 frames per second. The images are transmitted through a movie projector at the same rate as they were recorded, with a Geneva drive ensuring that each frame remains still during its short projection time. A rotating shutter causes stroboscopic intervals of darkness, but the viewer does not notice the interruptions due to flicker fusion. The apparent motion on the screen is the result of the fact that the visual sense cannot discern the individual images at high speeds, so the impressions of the images blend with the dark intervals and are thus linked together to produce the illusion of one moving image. An analogous optical soundtrack (a graphic recording of the spoken words, music, and other sounds) runs along a portion of the film exclusively reserved for it, and was not projected. Contemporary films are usually fully digital through the entire process of production, distribution, and exhibition.
#
# Artificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, particularly computer systems. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals. Such machines may be called AIs. High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., ChatGPT and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it's not labeled AI anymore." Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and support for robotics. General intelligence—the ability to complete any task performed by a human on an at least equal level—is among the field's long-term goals. To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields. Artificial intelligence was founded as an academic discipline in 1956, and the field went through multiple cycles of optimism throughout its history, followed by periods of disappointment and loss of funding, known as AI winters. Funding and interest vastly increased after 2012 when deep learning outperformed previous AI techniques. This growth accelerated further after 2017 with the transformer architecture, and by the early 2020s many billions of dollars were being invested in AI and the field experienced rapid ongoing progress in what has become known as the AI boom. The emergence of advanced generative AI in the midst of the AI boom and its ability to create and modify content exposed several unintended consequences and harms in the present and raised concerns about the risks of AI and its long-term effects in the future, prompting discussions about regulatory policies to ensure the safety and benefits of the technology.

# %%
with open('text_for_llm-1.txt') as f:
    [print(line) for line in f.readlines()]
# Out:
# Art describes a diverse range of cultural activity centered around works utilizing creative or imaginative talents, which are expected to evoke a worthwhile experience,[1] generally through an expression of emotional power, conceptual ideas, technical proficiency, and/or beauty. There is no generally agreed definition of what constitutes art, and its interpretation has varied greatly throughout history and across cultures. In the Western tradition, the three classical branches of visual art are painting, sculpture, and architecture. Theatre, dance, and other performing arts, as well as literature, music, film and other media such as interactive media, are included in a broader definition of "the arts". Until the 17th century, art referred to any skill or mastery and was not differentiated from crafts or sciences. In modern usage after the 17th century, where aesthetic considerations are paramount, the fine arts are separated and distinguished from acquired skills in general, such as the decorative or applied arts. The nature of art and related concepts, such as creativity and interpretation, are explored in a branch of philosophy known as aesthetics. The resulting artworks are studied in the professional fields of art criticism and the history of art.
#
#
#
# A film, also known as a movie or motion picture, is a work of visual art that simulates experiences and otherwise communicates ideas, stories, perceptions, emotions, or atmosphere through the use of moving images that are generally, since the 1930s, synchronized with sound and (less commonly) other sensory stimulations.[1] The word "cinema" is borrowed from the French cinéma, an abbreviation of cinématographe (term coined by the Lumière brothers in the 1890s), from Ancient Greek meaning "recording movement". The word is today usually used to refer to either a purpose-built venue for screening films, known as a movie theater in the US; the film industry; the overall art form of specifically just filmmaking. The moving images of a film are created by photographing actual scenes with a motion-picture camera, by photographing drawings or miniature models using traditional animation techniques, by means of CGI and computer animation, or by a combination of some or all of these techniques, and other visual effects. Before the introduction of digital production, a series of still images were recorded on a strip of chemically sensitized celluloid (photographic film stock), usually at a rate of 24 frames per second. The images are transmitted through a movie projector at the same rate as they were recorded, with a Geneva drive ensuring that each frame remains still during its short projection time. A rotating shutter causes stroboscopic intervals of darkness, but the viewer does not notice the interruptions due to flicker fusion. The apparent motion on the screen is the result of the fact that the visual sense cannot discern the individual images at high speeds, so the impressions of the images blend with the dark intervals and are thus linked together to produce the illusion of one moving image. An analogous optical soundtrack (a graphic recording of the spoken words, music, and other sounds) runs along a portion of the film exclusively reserved for it, and was not projected. Contemporary films are usually fully digital through the entire process of production, distribution, and exhibition.
#
#
#
# Artificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, particularly computer systems. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals. Such machines may be called AIs. High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., ChatGPT and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it's not labeled AI anymore." Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and support for robotics. General intelligence—the ability to complete any task performed by a human on an at least equal level—is among the field's long-term goals. To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields. Artificial intelligence was founded as an academic discipline in 1956, and the field went through multiple cycles of optimism throughout its history, followed by periods of disappointment and loss of funding, known as AI winters. Funding and interest vastly increased after 2012 when deep learning outperformed previous AI techniques. This growth accelerated further after 2017 with the transformer architecture, and by the early 2020s many billions of dollars were being invested in AI and the field experienced rapid ongoing progress in what has become known as the AI boom. The emergence of advanced generative AI in the midst of the AI boom and its ability to create and modify content exposed several unintended consequences and harms in the present and raised concerns about the risks of AI and its long-term effects in the future, prompting discussions about regulatory policies to ensure the safety and benefits of the technology.

# %%
with open('text_for_llm-1.txt') as f:
    [print(line.strip()) for line in f.readlines()]
# Out:
# Art describes a diverse range of cultural activity centered around works utilizing creative or imaginative talents, which are expected to evoke a worthwhile experience,[1] generally through an expression of emotional power, conceptual ideas, technical proficiency, and/or beauty. There is no generally agreed definition of what constitutes art, and its interpretation has varied greatly throughout history and across cultures. In the Western tradition, the three classical branches of visual art are painting, sculpture, and architecture. Theatre, dance, and other performing arts, as well as literature, music, film and other media such as interactive media, are included in a broader definition of "the arts". Until the 17th century, art referred to any skill or mastery and was not differentiated from crafts or sciences. In modern usage after the 17th century, where aesthetic considerations are paramount, the fine arts are separated and distinguished from acquired skills in general, such as the decorative or applied arts. The nature of art and related concepts, such as creativity and interpretation, are explored in a branch of philosophy known as aesthetics. The resulting artworks are studied in the professional fields of art criticism and the history of art.
#
# A film, also known as a movie or motion picture, is a work of visual art that simulates experiences and otherwise communicates ideas, stories, perceptions, emotions, or atmosphere through the use of moving images that are generally, since the 1930s, synchronized with sound and (less commonly) other sensory stimulations.[1] The word "cinema" is borrowed from the French cinéma, an abbreviation of cinématographe (term coined by the Lumière brothers in the 1890s), from Ancient Greek meaning "recording movement". The word is today usually used to refer to either a purpose-built venue for screening films, known as a movie theater in the US; the film industry; the overall art form of specifically just filmmaking. The moving images of a film are created by photographing actual scenes with a motion-picture camera, by photographing drawings or miniature models using traditional animation techniques, by means of CGI and computer animation, or by a combination of some or all of these techniques, and other visual effects. Before the introduction of digital production, a series of still images were recorded on a strip of chemically sensitized celluloid (photographic film stock), usually at a rate of 24 frames per second. The images are transmitted through a movie projector at the same rate as they were recorded, with a Geneva drive ensuring that each frame remains still during its short projection time. A rotating shutter causes stroboscopic intervals of darkness, but the viewer does not notice the interruptions due to flicker fusion. The apparent motion on the screen is the result of the fact that the visual sense cannot discern the individual images at high speeds, so the impressions of the images blend with the dark intervals and are thus linked together to produce the illusion of one moving image. An analogous optical soundtrack (a graphic recording of the spoken words, music, and other sounds) runs along a portion of the film exclusively reserved for it, and was not projected. Contemporary films are usually fully digital through the entire process of production, distribution, and exhibition.
#
# Artificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, particularly computer systems. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals. Such machines may be called AIs. High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., ChatGPT and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it's not labeled AI anymore." Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and support for robotics. General intelligence—the ability to complete any task performed by a human on an at least equal level—is among the field's long-term goals. To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields. Artificial intelligence was founded as an academic discipline in 1956, and the field went through multiple cycles of optimism throughout its history, followed by periods of disappointment and loss of funding, known as AI winters. Funding and interest vastly increased after 2012 when deep learning outperformed previous AI techniques. This growth accelerated further after 2017 with the transformer architecture, and by the early 2020s many billions of dollars were being invested in AI and the field experienced rapid ongoing progress in what has become known as the AI boom. The emergence of advanced generative AI in the midst of the AI boom and its ability to create and modify content exposed several unintended consequences and harms in the present and raised concerns about the risks of AI and its long-term effects in the future, prompting discussions about regulatory policies to ensure the safety and benefits of the technology.

# %%
with open('readme.txt', 'w') as f:
    f.write('readme')

# %%
lines = ['Readme', 'How to write text files in Python']
with open('readme.txt', 'w') as f:
    for line in lines:
        f.write(line)
        f.write('\n')

# %%
more_lines = ['', 'Append text files', 'The End']

with open('readme.txt', 'a') as f:
    f.write('\n'.join(more_lines))

# %%
with open('readme1.txt', 'w') as f:
    f.write('Create a new text file!')

# %%
import os.path
path_to_file = 'readme.txt'
os.path.exists(path_to_file)
# Out:
# True

# %%
from pathlib import Path

path_to_file = 'readme.txt'
path = Path(path_to_file)

if path.is_file():
    print(f'The file {path_to_file} exists')
else:
    print(f'The file {path_to_file} does not exist')
# Out:
# The file readme.txt exists

# %%
import csv

with open('music.csv', 'r') as f:
    csv_reader = csv.reader(f)
    for line in csv_reader:
        # process each line
        print(line)
# Out:
# ['age', 'gender', 'genre']
# ['20', '1', 'HipHop']
# ['23', '1', 'HipHop']
# ['25', '1', 'HipHop']
# ['26', '1', 'Jazz']
# ['29', '1', 'Jazz']
# ['30', '1', 'Jazz']
# ['31', '1', 'Classical']
# ['33', '1', 'Classical']
# ['37', '1', 'Classical']
# ['20', '0', 'Dance']
# ['21', '0', 'Dance']
# ['25', '0', 'Dance']
# ['26', '0', 'Acoustic']
# ['27', '0', 'Acoustic']
# ['30', '0', 'Acoustic']
# ['31', '0', 'Classical']
# ['34', '0', 'Classical']
# ['35', '0', 'Classical']

# %%
import csv

with open('country.csv', encoding="utf8") as f:
    csv_reader = csv.reader(f)
    for line in csv_reader:
        print(line)
# Out:
# ['name', 'area', 'country_code2', 'country_code3']
# ['Afghanistan', '652090.00', 'AF', 'AFG']
# ['Albania', '28748.00', 'AL', 'ALB']
# ['Algeria', '2381741.00', 'DZ', 'DZA']
# ['American Samoa', '199.00', 'AS', 'ASM']
# ['Andorra', '468.00', 'AD', 'AND']
# ['Angola', '1246700.00', 'AO', 'AGO']
# ['Anguilla', '96.00', 'AI', 'AIA']
# ['Antarctica', '13120000.00', 'AQ', 'ATA']
# ['Antigua and Barbuda', '442.00', 'AG', 'ATG']
# ['Argentina', '2780400.00', 'AR', 'ARG']
# ['Armenia', '29800.00', 'AM', 'ARM']
# ['Aruba', '193.00', 'AW', 'ABW']
# ['Australia', '7741220.00', 'AU', 'AUS']
# ['Austria', '83859.00', 'AT', 'AUT']
# ['Azerbaijan', '86600.00', 'AZ', 'AZE']
# ['Bahamas', '13878.00', 'BS', 'BHS']
# ['Bahrain', '694.00', 'BH', 'BHR']
# ['Bangladesh', '143998.00', 'BD', 'BGD']
# ['Barbados', '430.00', 'BB', 'BRB']
# ['Belarus', '207600.00', 'BY', 'BLR']
# ['Belgium', '30518.00', 'BE', 'BEL']
# ['Belize', '22696.00', 'BZ', 'BLZ']
# ['Benin', '112622.00', 'BJ', 'BEN']
# ['Bermuda', '53.00', 'BM', 'BMU']
# ['Bhutan', '47000.00', 'BT', 'BTN']
# ['Bolivia', '1098581.00', 'BO', 'BOL']
# ['Bosnia and Herzegovina', '51197.00', 'BA', 'BIH']
# ['Botswana', '581730.00', 'BW', 'BWA']
# ['Bouvet Island', '59.00', 'BV', 'BVT']
# ['Brazil', '8547403.00', 'BR', 'BRA']
# ['British Indian Ocean Territory', '78.00', 'IO', 'IOT']
# ['Brunei', '5765.00', 'BN', 'BRN']
# ['Bulgaria', '110994.00', 'BG', 'BGR']
# ['Burkina Faso', '274000.00', 'BF', 'BFA']
# ['Burundi', '27834.00', 'BI', 'BDI']
# ['Cambodia', '181035.00', 'KH', 'KHM']
# ['Cameroon', '475442.00', 'CM', 'CMR']
# ['Canada', '9970610.00', 'CA', 'CAN']
# ['Cape Verde', '4033.00', 'CV', 'CPV']
# ['Cayman Islands', '264.00', 'KY', 'CYM']
# ['Central African Republic', '622984.00', 'CF', 'CAF']
# ['Chad', '1284000.00', 'TD', 'TCD']
# ['Chile', '756626.00', 'CL', 'CHL']
# ['China', '9572900.00', 'CN', 'CHN']
# ['Christmas Island', '135.00', 'CX', 'CXR']
# ['Cocos (Keeling) Islands', '14.00', 'CC', 'CCK']
# ['Colombia', '1138914.00', 'CO', 'COL']
# ['Comoros', '1862.00', 'KM', 'COM']
# ['Congo', '342000.00', 'CG', 'COG']
# ['Cook Islands', '236.00', 'CK', 'COK']
# ['Costa Rica', '51100.00', 'CR', 'CRI']
# ['Côte d’Ivoire', '322463.00', 'CI', 'CIV']
# ['Croatia', '56538.00', 'HR', 'HRV']
# ['Cuba', '110861.00', 'CU', 'CUB']
# ['Cyprus', '9251.00', 'CY', 'CYP']
# ['Czech Republic', '78866.00', 'CZ', 'CZE']
# ['Denmark', '43094.00', 'DK', 'DNK']
# ['Djibouti', '23200.00', 'DJ', 'DJI']
# ['Dominica', '751.00', 'DM', 'DMA']
# ['Dominican Republic', '48511.00', 'DO', 'DOM']
# ['East Timor', '14874.00', 'TP', 'TMP']
# ['Ecuador', '283561.00', 'EC', 'ECU']
# ['Egypt', '1001449.00', 'EG', 'EGY']
# ['El Salvador', '21041.00', 'SV', 'SLV']
# ['Equatorial Guinea', '28051.00', 'GQ', 'GNQ']
# ['Eritrea', '117600.00', 'ER', 'ERI']
# ['Estonia', '45227.00', 'EE', 'EST']
# ['Ethiopia', '1104300.00', 'ET', 'ETH']
# ['Falkland Islands', '12173.00', 'FK', 'FLK']
# ['Faroe Islands', '1399.00', 'FO', 'FRO']
# ['Federated States of Micronesia', '702.00', 'FM', 'FSM']
# ['Fiji Islands', '18274.00', 'FJ', 'FJI']
# ['Finland', '338145.00', 'FI', 'FIN']
# ['France', '551500.00', 'FR', 'FRA']
# ['French Guiana', '90000.00', 'GF', 'GUF']
# ['French Polynesia', '4000.00', 'PF', 'PYF']
# ['French Southern territories', '7780.00', 'TF', 'ATF']
# ['Gabon', '267668.00', 'GA', 'GAB']
# ['Gambia', '11295.00', 'GM', 'GMB']
# ['Georgia', '69700.00', 'GE', 'GEO']
# ['Germany', '357022.00', 'DE', 'DEU']
# ['Ghana', '238533.00', 'GH', 'GHA']
# ['Gibraltar', '6.00', 'GI', 'GIB']
# ['Greece', '131626.00', 'GR', 'GRC']
# ['Greenland', '2166090.00', 'GL', 'GRL']
# ['Grenada', '344.00', 'GD', 'GRD']
# ['Guadeloupe', '1705.00', 'GP', 'GLP']
# ['Guam', '549.00', 'GU', 'GUM']
# ['Guatemala', '108889.00', 'GT', 'GTM']
# ['Guinea', '245857.00', 'GN', 'GIN']
# ['Guinea-Bissau', '36125.00', 'GW', 'GNB']
# ['Guyana', '214969.00', 'GY', 'GUY']
# ['Haiti', '27750.00', 'HT', 'HTI']
# ['Heard Island and McDonald Islands', '359.00', 'HM', 'HMD']
# ['Holy See (Vatican City State)', '0.40', 'VA', 'VAT']
# ['Honduras', '112088.00', 'HN', 'HND']
# ['Hong Kong', '1075.00', 'HK', 'HKG']
# ['Hungary', '93030.00', 'HU', 'HUN']
# ['Iceland', '103000.00', 'IS', 'ISL']
# ['India', '3287263.00', 'IN', 'IND']
# ['Indonesia', '1904569.00', 'ID', 'IDN']
# ['Iran', '1648195.00', 'IR', 'IRN']
# ['Iraq', '438317.00', 'IQ', 'IRQ']
# ['Ireland', '70273.00', 'IE', 'IRL']
# ['Israel', '21056.00', 'IL', 'ISR']
# ['Italy', '301316.00', 'IT', 'ITA']
# ['Jamaica', '10990.00', 'JM', 'JAM']
# ['Japan', '377829.00', 'JP', 'JPN']
# ['Jordan', '88946.00', 'JO', 'JOR']
# ['Kazakstan', '2724900.00', 'KZ', 'KAZ']
# ['Kenya', '580367.00', 'KE', 'KEN']
# ['Kiribati', '726.00', 'KI', 'KIR']
# ['Kuwait', '17818.00', 'KW', 'KWT']
# ['Kyrgyzstan', '199900.00', 'KG', 'KGZ']
# ['Laos', '236800.00', 'LA', 'LAO']
# ['Latvia', '64589.00', 'LV', 'LVA']
# ['Lebanon', '10400.00', 'LB', 'LBN']
# ['Lesotho', '30355.00', 'LS', 'LSO']
# ['Liberia', '111369.00', 'LR', 'LBR']
# ['Libyan Arab Jamahiriya', '1759540.00', 'LY', 'LBY']
# ['Liechtenstein', '160.00', 'LI', 'LIE']
# ['Lithuania', '65301.00', 'LT', 'LTU']
# ['Luxembourg', '2586.00', 'LU', 'LUX']
# ['Macao', '18.00', 'MO', 'MAC']
# ['Macedonia', '25713.00', 'MK', 'MKD']
# ['Madagascar', '587041.00', 'MG', 'MDG']
# ['Malawi', '118484.00', 'MW', 'MWI']
# ['Malaysia', '329758.00', 'MY', 'MYS']
# ['Maldives', '298.00', 'MV', 'MDV']
# ['Mali', '1240192.00', 'ML', 'MLI']
# ['Malta', '316.00', 'MT', 'MLT']
# ['Marshall Islands', '181.00', 'MH', 'MHL']
# ['Martinique', '1102.00', 'MQ', 'MTQ']
# ['Mauritania', '1025520.00', 'MR', 'MRT']
# ['Mauritius', '2040.00', 'MU', 'MUS']
# ['Mayotte', '373.00', 'YT', 'MYT']
# ['Mexico', '1958201.00', 'MX', 'MEX']
# ['Moldova', '33851.00', 'MD', 'MDA']
# ['Monaco', '1.50', 'MC', 'MCO']
# ['Mongolia', '1566500.00', 'MN', 'MNG']
# ['Montserrat', '102.00', 'MS', 'MSR']
# ['Morocco', '446550.00', 'MA', 'MAR']
# ['Mozambique', '801590.00', 'MZ', 'MOZ']
# ['Myanmar', '676578.00', 'MM', 'MMR']
# ['Namibia', '824292.00', 'NA', 'NAM']
# ['Nauru', '21.00', 'NR', 'NRU']
# ['Nepal', '147181.00', 'NP', 'NPL']
# ['Netherlands', '41526.00', 'NL', 'NLD']
# ['Netherlands Antilles', '800.00', 'AN', 'ANT']
# ['New Caledonia', '18575.00', 'NC', 'NCL']
# ['New Zealand', '270534.00', 'NZ', 'NZL']
# ['Nicaragua', '130000.00', 'NI', 'NIC']
# ['Niger', '1267000.00', 'NE', 'NER']
# ['Nigeria', '923768.00', 'NG', 'NGA']
# ['Niue', '260.00', 'NU', 'NIU']
# ['Norfolk Island', '36.00', 'NF', 'NFK']
# ['North Korea', '120538.00', 'KP', 'PRK']
# ['Northern Mariana Islands', '464.00', 'MP', 'MNP']
# ['Norway', '323877.00', 'NO', 'NOR']
# ['Oman', '309500.00', 'OM', 'OMN']
# ['Pakistan', '796095.00', 'PK', 'PAK']
# ['Palau', '459.00', 'PW', 'PLW']
# ['Palestine', '6257.00', 'PS', 'PSE']
# ['Panama', '75517.00', 'PA', 'PAN']
# ['Papua New Guinea', '462840.00', 'PG', 'PNG']
# ['Paraguay', '406752.00', 'PY', 'PRY']
# ['Peru', '1285216.00', 'PE', 'PER']
# ['Philippines', '300000.00', 'PH', 'PHL']
# ['Pitcairn', '49.00', 'PN', 'PCN']
# ['Poland', '323250.00', 'PL', 'POL']
# ['Portugal', '91982.00', 'PT', 'PRT']
# ['Puerto Rico', '8875.00', 'PR', 'PRI']
# ['Qatar', '11000.00', 'QA', 'QAT']
# ['Réunion', '2510.00', 'RE', 'REU']
# ['Romania', '238391.00', 'RO', 'ROM']
# ['Russian Federation', '17075400.00', 'RU', 'RUS']
# ['Rwanda', '26338.00', 'RW', 'RWA']
# ['Saint Helena', '314.00', 'SH', 'SHN']
# ['Saint Kitts and Nevis', '261.00', 'KN', 'KNA']
# ['Saint Lucia', '622.00', 'LC', 'LCA']
# ['Saint Pierre and Miquelon', '242.00', 'PM', 'SPM']
# ['Saint Vincent and the Grenadines', '388.00', 'VC', 'VCT']
# ['Samoa', '2831.00', 'WS', 'WSM']
# ['San Marino', '61.00', 'SM', 'SMR']
# ['Sao Tome and Principe', '964.00', 'ST', 'STP']
# ['Saudi Arabia', '2149690.00', 'SA', 'SAU']
# ['Senegal', '196722.00', 'SN', 'SEN']
# ['Seychelles', '455.00', 'SC', 'SYC']
# ['Sierra Leone', '71740.00', 'SL', 'SLE']
# ['Singapore', '618.00', 'SG', 'SGP']
# ['Slovakia', '49012.00', 'SK', 'SVK']
# ['Slovenia', '20256.00', 'SI', 'SVN']
# ['Solomon Islands', '28896.00', 'SB', 'SLB']
# ['Somalia', '637657.00', 'SO', 'SOM']
# ['South Africa', '1221037.00', 'ZA', 'ZAF']
# ['South Georgia and the South Sandwich Islands', '3903.00', 'GS', 'SGS']
# ['South Korea', '99434.00', 'KR', 'KOR']
# ['Spain', '505992.00', 'ES', 'ESP']
# ['Sri Lanka', '65610.00', 'LK', 'LKA']
# ['Sudan', '2505813.00', 'SD', 'SDN']
# ['Suriname', '163265.00', 'SR', 'SUR']
# ['Svalbard and Jan Mayen', '62422.00', 'SJ', 'SJM']
# ['Swaziland', '17364.00', 'SZ', 'SWZ']
# ['Sweden', '449964.00', 'SE', 'SWE']
# ['Switzerland', '41284.00', 'CH', 'CHE']
# ['Syria', '185180.00', 'SY', 'SYR']
# ['Taiwan', '36188.00', 'TW', 'TWN']
# ['Tajikistan', '143100.00', 'TJ', 'TJK']
# ['Tanzania', '883749.00', 'TZ', 'TZA']
# ['Thailand', '513115.00', 'TH', 'THA']
# ['The Democratic Republic of the Congo', '2344858.00', 'CD', 'COD']
# ['Togo', '56785.00', 'TG', 'TGO']
# ['Tokelau', '12.00', 'TK', 'TKL']
# ['Tonga', '650.00', 'TO', 'TON']
# ['Trinidad and Tobago', '5130.00', 'TT', 'TTO']
# ['Tunisia', '163610.00', 'TN', 'TUN']
# ['Turkey', '774815.00', 'TR', 'TUR']
# ['Turkmenistan', '488100.00', 'TM', 'TKM']
# ['Turks and Caicos Islands', '430.00', 'TC', 'TCA']
# ['Tuvalu', '26.00', 'TV', 'TUV']
# ['Uganda', '241038.00', 'UG', 'UGA']
# ['Ukraine', '603700.00', 'UA', 'UKR']
# ['United Arab Emirates', '83600.00', 'AE', 'ARE']
# ['United Kingdom', '242900.00', 'GB', 'GBR']
# ['United States', '9363520.00', 'US', 'USA']
# ['United States Minor Outlying Islands', '16.00', 'UM', 'UMI']
# ['Uruguay', '175016.00', 'UY', 'URY']
# ['Uzbekistan', '447400.00', 'UZ', 'UZB']
# ['Vanuatu', '12189.00', 'VU', 'VUT']
# ['Venezuela', '912050.00', 'VE', 'VEN']
# ['Vietnam', '331689.00', 'VN', 'VNM']
# ['Virgin Islands, British', '151.00', 'VG', 'VGB']
# ['Virgin Islands, U.S.', '347.00', 'VI', 'VIR']
# ['Wallis and Futuna', '200.00', 'WF', 'WLF']
# ['Western Sahara', '266000.00', 'EH', 'ESH']
# ['Yemen', '527968.00', 'YE', 'YEM']
# ['Yugoslavia', '102173.00', 'YU', 'YUG']
# ['Zambia', '752618.00', 'ZM', 'ZMB']
# ['Zimbabwe', '390757.00', 'ZW', 'ZWE']

# %%
import csv

with open('country.csv', encoding="utf8") as f:
    csv_reader = csv.reader(f)
    for line_no, line in enumerate(csv_reader, 1):
        if line_no == 1:
            print('Header:')
            print(line)  # header
            print('Data:')
        else:
            print(line)  # data
# Out:
# Header:
# ['name', 'area', 'country_code2', 'country_code3']
# Data:
# ['Afghanistan', '652090.00', 'AF', 'AFG']
# ['Albania', '28748.00', 'AL', 'ALB']
# ['Algeria', '2381741.00', 'DZ', 'DZA']
# ['American Samoa', '199.00', 'AS', 'ASM']
# ['Andorra', '468.00', 'AD', 'AND']
# ['Angola', '1246700.00', 'AO', 'AGO']
# ['Anguilla', '96.00', 'AI', 'AIA']
# ['Antarctica', '13120000.00', 'AQ', 'ATA']
# ['Antigua and Barbuda', '442.00', 'AG', 'ATG']
# ['Argentina', '2780400.00', 'AR', 'ARG']
# ['Armenia', '29800.00', 'AM', 'ARM']
# ['Aruba', '193.00', 'AW', 'ABW']
# ['Australia', '7741220.00', 'AU', 'AUS']
# ['Austria', '83859.00', 'AT', 'AUT']
# ['Azerbaijan', '86600.00', 'AZ', 'AZE']
# ['Bahamas', '13878.00', 'BS', 'BHS']
# ['Bahrain', '694.00', 'BH', 'BHR']
# ['Bangladesh', '143998.00', 'BD', 'BGD']
# ['Barbados', '430.00', 'BB', 'BRB']
# ['Belarus', '207600.00', 'BY', 'BLR']
# ['Belgium', '30518.00', 'BE', 'BEL']
# ['Belize', '22696.00', 'BZ', 'BLZ']
# ['Benin', '112622.00', 'BJ', 'BEN']
# ['Bermuda', '53.00', 'BM', 'BMU']
# ['Bhutan', '47000.00', 'BT', 'BTN']
# ['Bolivia', '1098581.00', 'BO', 'BOL']
# ['Bosnia and Herzegovina', '51197.00', 'BA', 'BIH']
# ['Botswana', '581730.00', 'BW', 'BWA']
# ['Bouvet Island', '59.00', 'BV', 'BVT']
# ['Brazil', '8547403.00', 'BR', 'BRA']
# ['British Indian Ocean Territory', '78.00', 'IO', 'IOT']
# ['Brunei', '5765.00', 'BN', 'BRN']
# ['Bulgaria', '110994.00', 'BG', 'BGR']
# ['Burkina Faso', '274000.00', 'BF', 'BFA']
# ['Burundi', '27834.00', 'BI', 'BDI']
# ['Cambodia', '181035.00', 'KH', 'KHM']
# ['Cameroon', '475442.00', 'CM', 'CMR']
# ['Canada', '9970610.00', 'CA', 'CAN']
# ['Cape Verde', '4033.00', 'CV', 'CPV']
# ['Cayman Islands', '264.00', 'KY', 'CYM']
# ['Central African Republic', '622984.00', 'CF', 'CAF']
# ['Chad', '1284000.00', 'TD', 'TCD']
# ['Chile', '756626.00', 'CL', 'CHL']
# ['China', '9572900.00', 'CN', 'CHN']
# ['Christmas Island', '135.00', 'CX', 'CXR']
# ['Cocos (Keeling) Islands', '14.00', 'CC', 'CCK']
# ['Colombia', '1138914.00', 'CO', 'COL']
# ['Comoros', '1862.00', 'KM', 'COM']
# ['Congo', '342000.00', 'CG', 'COG']
# ['Cook Islands', '236.00', 'CK', 'COK']
# ['Costa Rica', '51100.00', 'CR', 'CRI']
# ['Côte d’Ivoire', '322463.00', 'CI', 'CIV']
# ['Croatia', '56538.00', 'HR', 'HRV']
# ['Cuba', '110861.00', 'CU', 'CUB']
# ['Cyprus', '9251.00', 'CY', 'CYP']
# ['Czech Republic', '78866.00', 'CZ', 'CZE']
# ['Denmark', '43094.00', 'DK', 'DNK']
# ['Djibouti', '23200.00', 'DJ', 'DJI']
# ['Dominica', '751.00', 'DM', 'DMA']
# ['Dominican Republic', '48511.00', 'DO', 'DOM']
# ['East Timor', '14874.00', 'TP', 'TMP']
# ['Ecuador', '283561.00', 'EC', 'ECU']
# ['Egypt', '1001449.00', 'EG', 'EGY']
# ['El Salvador', '21041.00', 'SV', 'SLV']
# ['Equatorial Guinea', '28051.00', 'GQ', 'GNQ']
# ['Eritrea', '117600.00', 'ER', 'ERI']
# ['Estonia', '45227.00', 'EE', 'EST']
# ['Ethiopia', '1104300.00', 'ET', 'ETH']
# ['Falkland Islands', '12173.00', 'FK', 'FLK']
# ['Faroe Islands', '1399.00', 'FO', 'FRO']
# ['Federated States of Micronesia', '702.00', 'FM', 'FSM']
# ['Fiji Islands', '18274.00', 'FJ', 'FJI']
# ['Finland', '338145.00', 'FI', 'FIN']
# ['France', '551500.00', 'FR', 'FRA']
# ['French Guiana', '90000.00', 'GF', 'GUF']
# ['French Polynesia', '4000.00', 'PF', 'PYF']
# ['French Southern territories', '7780.00', 'TF', 'ATF']
# ['Gabon', '267668.00', 'GA', 'GAB']
# ['Gambia', '11295.00', 'GM', 'GMB']
# ['Georgia', '69700.00', 'GE', 'GEO']
# ['Germany', '357022.00', 'DE', 'DEU']
# ['Ghana', '238533.00', 'GH', 'GHA']
# ['Gibraltar', '6.00', 'GI', 'GIB']
# ['Greece', '131626.00', 'GR', 'GRC']
# ['Greenland', '2166090.00', 'GL', 'GRL']
# ['Grenada', '344.00', 'GD', 'GRD']
# ['Guadeloupe', '1705.00', 'GP', 'GLP']
# ['Guam', '549.00', 'GU', 'GUM']
# ['Guatemala', '108889.00', 'GT', 'GTM']
# ['Guinea', '245857.00', 'GN', 'GIN']
# ['Guinea-Bissau', '36125.00', 'GW', 'GNB']
# ['Guyana', '214969.00', 'GY', 'GUY']
# ['Haiti', '27750.00', 'HT', 'HTI']
# ['Heard Island and McDonald Islands', '359.00', 'HM', 'HMD']
# ['Holy See (Vatican City State)', '0.40', 'VA', 'VAT']
# ['Honduras', '112088.00', 'HN', 'HND']
# ['Hong Kong', '1075.00', 'HK', 'HKG']
# ['Hungary', '93030.00', 'HU', 'HUN']
# ['Iceland', '103000.00', 'IS', 'ISL']
# ['India', '3287263.00', 'IN', 'IND']
# ['Indonesia', '1904569.00', 'ID', 'IDN']
# ['Iran', '1648195.00', 'IR', 'IRN']
# ['Iraq', '438317.00', 'IQ', 'IRQ']
# ['Ireland', '70273.00', 'IE', 'IRL']
# ['Israel', '21056.00', 'IL', 'ISR']
# ['Italy', '301316.00', 'IT', 'ITA']
# ['Jamaica', '10990.00', 'JM', 'JAM']
# ['Japan', '377829.00', 'JP', 'JPN']
# ['Jordan', '88946.00', 'JO', 'JOR']
# ['Kazakstan', '2724900.00', 'KZ', 'KAZ']
# ['Kenya', '580367.00', 'KE', 'KEN']
# ['Kiribati', '726.00', 'KI', 'KIR']
# ['Kuwait', '17818.00', 'KW', 'KWT']
# ['Kyrgyzstan', '199900.00', 'KG', 'KGZ']
# ['Laos', '236800.00', 'LA', 'LAO']
# ['Latvia', '64589.00', 'LV', 'LVA']
# ['Lebanon', '10400.00', 'LB', 'LBN']
# ['Lesotho', '30355.00', 'LS', 'LSO']
# ['Liberia', '111369.00', 'LR', 'LBR']
# ['Libyan Arab Jamahiriya', '1759540.00', 'LY', 'LBY']
# ['Liechtenstein', '160.00', 'LI', 'LIE']
# ['Lithuania', '65301.00', 'LT', 'LTU']
# ['Luxembourg', '2586.00', 'LU', 'LUX']
# ['Macao', '18.00', 'MO', 'MAC']
# ['Macedonia', '25713.00', 'MK', 'MKD']
# ['Madagascar', '587041.00', 'MG', 'MDG']
# ['Malawi', '118484.00', 'MW', 'MWI']
# ['Malaysia', '329758.00', 'MY', 'MYS']
# ['Maldives', '298.00', 'MV', 'MDV']
# ['Mali', '1240192.00', 'ML', 'MLI']
# ['Malta', '316.00', 'MT', 'MLT']
# ['Marshall Islands', '181.00', 'MH', 'MHL']
# ['Martinique', '1102.00', 'MQ', 'MTQ']
# ['Mauritania', '1025520.00', 'MR', 'MRT']
# ['Mauritius', '2040.00', 'MU', 'MUS']
# ['Mayotte', '373.00', 'YT', 'MYT']
# ['Mexico', '1958201.00', 'MX', 'MEX']
# ['Moldova', '33851.00', 'MD', 'MDA']
# ['Monaco', '1.50', 'MC', 'MCO']
# ['Mongolia', '1566500.00', 'MN', 'MNG']
# ['Montserrat', '102.00', 'MS', 'MSR']
# ['Morocco', '446550.00', 'MA', 'MAR']
# ['Mozambique', '801590.00', 'MZ', 'MOZ']
# ['Myanmar', '676578.00', 'MM', 'MMR']
# ['Namibia', '824292.00', 'NA', 'NAM']
# ['Nauru', '21.00', 'NR', 'NRU']
# ['Nepal', '147181.00', 'NP', 'NPL']
# ['Netherlands', '41526.00', 'NL', 'NLD']
# ['Netherlands Antilles', '800.00', 'AN', 'ANT']
# ['New Caledonia', '18575.00', 'NC', 'NCL']
# ['New Zealand', '270534.00', 'NZ', 'NZL']
# ['Nicaragua', '130000.00', 'NI', 'NIC']
# ['Niger', '1267000.00', 'NE', 'NER']
# ['Nigeria', '923768.00', 'NG', 'NGA']
# ['Niue', '260.00', 'NU', 'NIU']
# ['Norfolk Island', '36.00', 'NF', 'NFK']
# ['North Korea', '120538.00', 'KP', 'PRK']
# ['Northern Mariana Islands', '464.00', 'MP', 'MNP']
# ['Norway', '323877.00', 'NO', 'NOR']
# ['Oman', '309500.00', 'OM', 'OMN']
# ['Pakistan', '796095.00', 'PK', 'PAK']
# ['Palau', '459.00', 'PW', 'PLW']
# ['Palestine', '6257.00', 'PS', 'PSE']
# ['Panama', '75517.00', 'PA', 'PAN']
# ['Papua New Guinea', '462840.00', 'PG', 'PNG']
# ['Paraguay', '406752.00', 'PY', 'PRY']
# ['Peru', '1285216.00', 'PE', 'PER']
# ['Philippines', '300000.00', 'PH', 'PHL']
# ['Pitcairn', '49.00', 'PN', 'PCN']
# ['Poland', '323250.00', 'PL', 'POL']
# ['Portugal', '91982.00', 'PT', 'PRT']
# ['Puerto Rico', '8875.00', 'PR', 'PRI']
# ['Qatar', '11000.00', 'QA', 'QAT']
# ['Réunion', '2510.00', 'RE', 'REU']
# ['Romania', '238391.00', 'RO', 'ROM']
# ['Russian Federation', '17075400.00', 'RU', 'RUS']
# ['Rwanda', '26338.00', 'RW', 'RWA']
# ['Saint Helena', '314.00', 'SH', 'SHN']
# ['Saint Kitts and Nevis', '261.00', 'KN', 'KNA']
# ['Saint Lucia', '622.00', 'LC', 'LCA']
# ['Saint Pierre and Miquelon', '242.00', 'PM', 'SPM']
# ['Saint Vincent and the Grenadines', '388.00', 'VC', 'VCT']
# ['Samoa', '2831.00', 'WS', 'WSM']
# ['San Marino', '61.00', 'SM', 'SMR']
# ['Sao Tome and Principe', '964.00', 'ST', 'STP']
# ['Saudi Arabia', '2149690.00', 'SA', 'SAU']
# ['Senegal', '196722.00', 'SN', 'SEN']
# ['Seychelles', '455.00', 'SC', 'SYC']
# ['Sierra Leone', '71740.00', 'SL', 'SLE']
# ['Singapore', '618.00', 'SG', 'SGP']
# ['Slovakia', '49012.00', 'SK', 'SVK']
# ['Slovenia', '20256.00', 'SI', 'SVN']
# ['Solomon Islands', '28896.00', 'SB', 'SLB']
# ['Somalia', '637657.00', 'SO', 'SOM']
# ['South Africa', '1221037.00', 'ZA', 'ZAF']
# ['South Georgia and the South Sandwich Islands', '3903.00', 'GS', 'SGS']
# ['South Korea', '99434.00', 'KR', 'KOR']
# ['Spain', '505992.00', 'ES', 'ESP']
# ['Sri Lanka', '65610.00', 'LK', 'LKA']
# ['Sudan', '2505813.00', 'SD', 'SDN']
# ['Suriname', '163265.00', 'SR', 'SUR']
# ['Svalbard and Jan Mayen', '62422.00', 'SJ', 'SJM']
# ['Swaziland', '17364.00', 'SZ', 'SWZ']
# ['Sweden', '449964.00', 'SE', 'SWE']
# ['Switzerland', '41284.00', 'CH', 'CHE']
# ['Syria', '185180.00', 'SY', 'SYR']
# ['Taiwan', '36188.00', 'TW', 'TWN']
# ['Tajikistan', '143100.00', 'TJ', 'TJK']
# ['Tanzania', '883749.00', 'TZ', 'TZA']
# ['Thailand', '513115.00', 'TH', 'THA']
# ['The Democratic Republic of the Congo', '2344858.00', 'CD', 'COD']
# ['Togo', '56785.00', 'TG', 'TGO']
# ['Tokelau', '12.00', 'TK', 'TKL']
# ['Tonga', '650.00', 'TO', 'TON']
# ['Trinidad and Tobago', '5130.00', 'TT', 'TTO']
# ['Tunisia', '163610.00', 'TN', 'TUN']
# ['Turkey', '774815.00', 'TR', 'TUR']
# ['Turkmenistan', '488100.00', 'TM', 'TKM']
# ['Turks and Caicos Islands', '430.00', 'TC', 'TCA']
# ['Tuvalu', '26.00', 'TV', 'TUV']
# ['Uganda', '241038.00', 'UG', 'UGA']
# ['Ukraine', '603700.00', 'UA', 'UKR']
# ['United Arab Emirates', '83600.00', 'AE', 'ARE']
# ['United Kingdom', '242900.00', 'GB', 'GBR']
# ['United States', '9363520.00', 'US', 'USA']
# ['United States Minor Outlying Islands', '16.00', 'UM', 'UMI']
# ['Uruguay', '175016.00', 'UY', 'URY']
# ['Uzbekistan', '447400.00', 'UZ', 'UZB']
# ['Vanuatu', '12189.00', 'VU', 'VUT']
# ['Venezuela', '912050.00', 'VE', 'VEN']
# ['Vietnam', '331689.00', 'VN', 'VNM']
# ['Virgin Islands, British', '151.00', 'VG', 'VGB']
# ['Virgin Islands, U.S.', '347.00', 'VI', 'VIR']
# ['Wallis and Futuna', '200.00', 'WF', 'WLF']
# ['Western Sahara', '266000.00', 'EH', 'ESH']
# ['Yemen', '527968.00', 'YE', 'YEM']
# ['Yugoslavia', '102173.00', 'YU', 'YUG']
# ['Zambia', '752618.00', 'ZM', 'ZMB']
# ['Zimbabwe', '390757.00', 'ZW', 'ZWE']

# %%
import csv

total_area = 0

# calculate the total area of all countries

with open('country.csv', encoding="utf8") as f:
    csv_reader = csv.reader(f)

    # skip the header
    next(csv_reader)

    # calculate total
    for line in csv_reader:
        total_area += float(line[1])

print(total_area)
# Out:
# 148956306.9

# %%
import csv

with open('country.csv', encoding="utf8") as f:
    csv_reader = csv.DictReader(f)
    # skip the header
    next(csv_reader)
    # show the data
    for line in csv_reader:
        print(f"The area of {line['name']} is {line['area']} km2")
# Out:
# The area of Albania is 28748.00 km2
# The area of Algeria is 2381741.00 km2
# The area of American Samoa is 199.00 km2
# The area of Andorra is 468.00 km2
# The area of Angola is 1246700.00 km2
# The area of Anguilla is 96.00 km2
# The area of Antarctica is 13120000.00 km2
# The area of Antigua and Barbuda is 442.00 km2
# The area of Argentina is 2780400.00 km2
# The area of Armenia is 29800.00 km2
# The area of Aruba is 193.00 km2
# The area of Australia is 7741220.00 km2
# The area of Austria is 83859.00 km2
# The area of Azerbaijan is 86600.00 km2
# The area of Bahamas is 13878.00 km2
# The area of Bahrain is 694.00 km2
# The area of Bangladesh is 143998.00 km2
# The area of Barbados is 430.00 km2
# The area of Belarus is 207600.00 km2
# The area of Belgium is 30518.00 km2
# The area of Belize is 22696.00 km2
# The area of Benin is 112622.00 km2
# The area of Bermuda is 53.00 km2
# The area of Bhutan is 47000.00 km2
# The area of Bolivia is 1098581.00 km2
# The area of Bosnia and Herzegovina is 51197.00 km2
# The area of Botswana is 581730.00 km2
# The area of Bouvet Island is 59.00 km2
# The area of Brazil is 8547403.00 km2
# The area of British Indian Ocean Territory is 78.00 km2
# The area of Brunei is 5765.00 km2
# The area of Bulgaria is 110994.00 km2
# The area of Burkina Faso is 274000.00 km2
# The area of Burundi is 27834.00 km2
# The area of Cambodia is 181035.00 km2
# The area of Cameroon is 475442.00 km2
# The area of Canada is 9970610.00 km2
# The area of Cape Verde is 4033.00 km2
# The area of Cayman Islands is 264.00 km2
# The area of Central African Republic is 622984.00 km2
# The area of Chad is 1284000.00 km2
# The area of Chile is 756626.00 km2
# The area of China is 9572900.00 km2
# The area of Christmas Island is 135.00 km2
# The area of Cocos (Keeling) Islands is 14.00 km2
# The area of Colombia is 1138914.00 km2
# The area of Comoros is 1862.00 km2
# The area of Congo is 342000.00 km2
# The area of Cook Islands is 236.00 km2
# The area of Costa Rica is 51100.00 km2
# The area of Côte d’Ivoire is 322463.00 km2
# The area of Croatia is 56538.00 km2
# The area of Cuba is 110861.00 km2
# The area of Cyprus is 9251.00 km2
# The area of Czech Republic is 78866.00 km2
# The area of Denmark is 43094.00 km2
# The area of Djibouti is 23200.00 km2
# The area of Dominica is 751.00 km2
# The area of Dominican Republic is 48511.00 km2
# The area of East Timor is 14874.00 km2
# The area of Ecuador is 283561.00 km2
# The area of Egypt is 1001449.00 km2
# The area of El Salvador is 21041.00 km2
# The area of Equatorial Guinea is 28051.00 km2
# The area of Eritrea is 117600.00 km2
# The area of Estonia is 45227.00 km2
# The area of Ethiopia is 1104300.00 km2
# The area of Falkland Islands is 12173.00 km2
# The area of Faroe Islands is 1399.00 km2
# The area of Federated States of Micronesia is 702.00 km2
# The area of Fiji Islands is 18274.00 km2
# The area of Finland is 338145.00 km2
# The area of France is 551500.00 km2
# The area of French Guiana is 90000.00 km2
# The area of French Polynesia is 4000.00 km2
# The area of French Southern territories is 7780.00 km2
# The area of Gabon is 267668.00 km2
# The area of Gambia is 11295.00 km2
# The area of Georgia is 69700.00 km2
# The area of Germany is 357022.00 km2
# The area of Ghana is 238533.00 km2
# The area of Gibraltar is 6.00 km2
# The area of Greece is 131626.00 km2
# The area of Greenland is 2166090.00 km2
# The area of Grenada is 344.00 km2
# The area of Guadeloupe is 1705.00 km2
# The area of Guam is 549.00 km2
# The area of Guatemala is 108889.00 km2
# The area of Guinea is 245857.00 km2
# The area of Guinea-Bissau is 36125.00 km2
# The area of Guyana is 214969.00 km2
# The area of Haiti is 27750.00 km2
# The area of Heard Island and McDonald Islands is 359.00 km2
# The area of Holy See (Vatican City State) is 0.40 km2
# The area of Honduras is 112088.00 km2
# The area of Hong Kong is 1075.00 km2
# The area of Hungary is 93030.00 km2
# The area of Iceland is 103000.00 km2
# The area of India is 3287263.00 km2
# The area of Indonesia is 1904569.00 km2
# The area of Iran is 1648195.00 km2
# The area of Iraq is 438317.00 km2
# The area of Ireland is 70273.00 km2
# The area of Israel is 21056.00 km2
# The area of Italy is 301316.00 km2
# The area of Jamaica is 10990.00 km2
# The area of Japan is 377829.00 km2
# The area of Jordan is 88946.00 km2
# The area of Kazakstan is 2724900.00 km2
# The area of Kenya is 580367.00 km2
# The area of Kiribati is 726.00 km2
# The area of Kuwait is 17818.00 km2
# The area of Kyrgyzstan is 199900.00 km2
# The area of Laos is 236800.00 km2
# The area of Latvia is 64589.00 km2
# The area of Lebanon is 10400.00 km2
# The area of Lesotho is 30355.00 km2
# The area of Liberia is 111369.00 km2
# The area of Libyan Arab Jamahiriya is 1759540.00 km2
# The area of Liechtenstein is 160.00 km2
# The area of Lithuania is 65301.00 km2
# The area of Luxembourg is 2586.00 km2
# The area of Macao is 18.00 km2
# The area of Macedonia is 25713.00 km2
# The area of Madagascar is 587041.00 km2
# The area of Malawi is 118484.00 km2
# The area of Malaysia is 329758.00 km2
# The area of Maldives is 298.00 km2
# The area of Mali is 1240192.00 km2
# The area of Malta is 316.00 km2
# The area of Marshall Islands is 181.00 km2
# The area of Martinique is 1102.00 km2
# The area of Mauritania is 1025520.00 km2
# The area of Mauritius is 2040.00 km2
# The area of Mayotte is 373.00 km2
# The area of Mexico is 1958201.00 km2
# The area of Moldova is 33851.00 km2
# The area of Monaco is 1.50 km2
# The area of Mongolia is 1566500.00 km2
# The area of Montserrat is 102.00 km2
# The area of Morocco is 446550.00 km2
# The area of Mozambique is 801590.00 km2
# The area of Myanmar is 676578.00 km2
# The area of Namibia is 824292.00 km2
# The area of Nauru is 21.00 km2
# The area of Nepal is 147181.00 km2
# The area of Netherlands is 41526.00 km2
# The area of Netherlands Antilles is 800.00 km2
# The area of New Caledonia is 18575.00 km2
# The area of New Zealand is 270534.00 km2
# The area of Nicaragua is 130000.00 km2
# The area of Niger is 1267000.00 km2
# The area of Nigeria is 923768.00 km2
# The area of Niue is 260.00 km2
# The area of Norfolk Island is 36.00 km2
# The area of North Korea is 120538.00 km2
# The area of Northern Mariana Islands is 464.00 km2
# The area of Norway is 323877.00 km2
# The area of Oman is 309500.00 km2
# The area of Pakistan is 796095.00 km2
# The area of Palau is 459.00 km2
# The area of Palestine is 6257.00 km2
# The area of Panama is 75517.00 km2
# The area of Papua New Guinea is 462840.00 km2
# The area of Paraguay is 406752.00 km2
# The area of Peru is 1285216.00 km2
# The area of Philippines is 300000.00 km2
# The area of Pitcairn is 49.00 km2
# The area of Poland is 323250.00 km2
# The area of Portugal is 91982.00 km2
# The area of Puerto Rico is 8875.00 km2
# The area of Qatar is 11000.00 km2
# The area of Réunion is 2510.00 km2
# The area of Romania is 238391.00 km2
# The area of Russian Federation is 17075400.00 km2
# The area of Rwanda is 26338.00 km2
# The area of Saint Helena is 314.00 km2
# The area of Saint Kitts and Nevis is 261.00 km2
# The area of Saint Lucia is 622.00 km2
# The area of Saint Pierre and Miquelon is 242.00 km2
# The area of Saint Vincent and the Grenadines is 388.00 km2
# The area of Samoa is 2831.00 km2
# The area of San Marino is 61.00 km2
# The area of Sao Tome and Principe is 964.00 km2
# The area of Saudi Arabia is 2149690.00 km2
# The area of Senegal is 196722.00 km2
# The area of Seychelles is 455.00 km2
# The area of Sierra Leone is 71740.00 km2
# The area of Singapore is 618.00 km2
# The area of Slovakia is 49012.00 km2
# The area of Slovenia is 20256.00 km2
# The area of Solomon Islands is 28896.00 km2
# The area of Somalia is 637657.00 km2
# The area of South Africa is 1221037.00 km2
# The area of South Georgia and the South Sandwich Islands is 3903.00 km2
# The area of South Korea is 99434.00 km2
# The area of Spain is 505992.00 km2
# The area of Sri Lanka is 65610.00 km2
# The area of Sudan is 2505813.00 km2
# The area of Suriname is 163265.00 km2
# The area of Svalbard and Jan Mayen is 62422.00 km2
# The area of Swaziland is 17364.00 km2
# The area of Sweden is 449964.00 km2
# The area of Switzerland is 41284.00 km2
# The area of Syria is 185180.00 km2
# The area of Taiwan is 36188.00 km2
# The area of Tajikistan is 143100.00 km2
# The area of Tanzania is 883749.00 km2
# The area of Thailand is 513115.00 km2
# The area of The Democratic Republic of the Congo is 2344858.00 km2
# The area of Togo is 56785.00 km2
# The area of Tokelau is 12.00 km2
# The area of Tonga is 650.00 km2
# The area of Trinidad and Tobago is 5130.00 km2
# The area of Tunisia is 163610.00 km2
# The area of Turkey is 774815.00 km2
# The area of Turkmenistan is 488100.00 km2
# The area of Turks and Caicos Islands is 430.00 km2
# The area of Tuvalu is 26.00 km2
# The area of Uganda is 241038.00 km2
# The area of Ukraine is 603700.00 km2
# The area of United Arab Emirates is 83600.00 km2
# The area of United Kingdom is 242900.00 km2
# The area of United States is 9363520.00 km2
# The area of United States Minor Outlying Islands is 16.00 km2
# The area of Uruguay is 175016.00 km2
# The area of Uzbekistan is 447400.00 km2
# The area of Vanuatu is 12189.00 km2
# The area of Venezuela is 912050.00 km2
# The area of Vietnam is 331689.00 km2
# The area of Virgin Islands, British is 151.00 km2
# The area of Virgin Islands, U.S. is 347.00 km2
# The area of Wallis and Futuna is 200.00 km2
# The area of Western Sahara is 266000.00 km2
# The area of Yemen is 527968.00 km2
# The area of Yugoslavia is 102173.00 km2
# The area of Zambia is 752618.00 km2
# The area of Zimbabwe is 390757.00 km2

# %%
import csv

fieldnames = ['country_name', 'area', 'code2', 'code3']

with open('country.csv', encoding="utf8") as f:
    csv_reader = csv.DictReader(f, fieldnames)
    next(csv_reader)
    for line in csv_reader:
        print(f"The area of {line['country_name']} is {line['area']} km2")
# Out:
# The area of Afghanistan is 652090.00 km2
# The area of Albania is 28748.00 km2
# The area of Algeria is 2381741.00 km2
# The area of American Samoa is 199.00 km2
# The area of Andorra is 468.00 km2
# The area of Angola is 1246700.00 km2
# The area of Anguilla is 96.00 km2
# The area of Antarctica is 13120000.00 km2
# The area of Antigua and Barbuda is 442.00 km2
# The area of Argentina is 2780400.00 km2
# The area of Armenia is 29800.00 km2
# The area of Aruba is 193.00 km2
# The area of Australia is 7741220.00 km2
# The area of Austria is 83859.00 km2
# The area of Azerbaijan is 86600.00 km2
# The area of Bahamas is 13878.00 km2
# The area of Bahrain is 694.00 km2
# The area of Bangladesh is 143998.00 km2
# The area of Barbados is 430.00 km2
# The area of Belarus is 207600.00 km2
# The area of Belgium is 30518.00 km2
# The area of Belize is 22696.00 km2
# The area of Benin is 112622.00 km2
# The area of Bermuda is 53.00 km2
# The area of Bhutan is 47000.00 km2
# The area of Bolivia is 1098581.00 km2
# The area of Bosnia and Herzegovina is 51197.00 km2
# The area of Botswana is 581730.00 km2
# The area of Bouvet Island is 59.00 km2
# The area of Brazil is 8547403.00 km2
# The area of British Indian Ocean Territory is 78.00 km2
# The area of Brunei is 5765.00 km2
# The area of Bulgaria is 110994.00 km2
# The area of Burkina Faso is 274000.00 km2
# The area of Burundi is 27834.00 km2
# The area of Cambodia is 181035.00 km2
# The area of Cameroon is 475442.00 km2
# The area of Canada is 9970610.00 km2
# The area of Cape Verde is 4033.00 km2
# The area of Cayman Islands is 264.00 km2
# The area of Central African Republic is 622984.00 km2
# The area of Chad is 1284000.00 km2
# The area of Chile is 756626.00 km2
# The area of China is 9572900.00 km2
# The area of Christmas Island is 135.00 km2
# The area of Cocos (Keeling) Islands is 14.00 km2
# The area of Colombia is 1138914.00 km2
# The area of Comoros is 1862.00 km2
# The area of Congo is 342000.00 km2
# The area of Cook Islands is 236.00 km2
# The area of Costa Rica is 51100.00 km2
# The area of Côte d’Ivoire is 322463.00 km2
# The area of Croatia is 56538.00 km2
# The area of Cuba is 110861.00 km2
# The area of Cyprus is 9251.00 km2
# The area of Czech Republic is 78866.00 km2
# The area of Denmark is 43094.00 km2
# The area of Djibouti is 23200.00 km2
# The area of Dominica is 751.00 km2
# The area of Dominican Republic is 48511.00 km2
# The area of East Timor is 14874.00 km2
# The area of Ecuador is 283561.00 km2
# The area of Egypt is 1001449.00 km2
# The area of El Salvador is 21041.00 km2
# The area of Equatorial Guinea is 28051.00 km2
# The area of Eritrea is 117600.00 km2
# The area of Estonia is 45227.00 km2
# The area of Ethiopia is 1104300.00 km2
# The area of Falkland Islands is 12173.00 km2
# The area of Faroe Islands is 1399.00 km2
# The area of Federated States of Micronesia is 702.00 km2
# The area of Fiji Islands is 18274.00 km2
# The area of Finland is 338145.00 km2
# The area of France is 551500.00 km2
# The area of French Guiana is 90000.00 km2
# The area of French Polynesia is 4000.00 km2
# The area of French Southern territories is 7780.00 km2
# The area of Gabon is 267668.00 km2
# The area of Gambia is 11295.00 km2
# The area of Georgia is 69700.00 km2
# The area of Germany is 357022.00 km2
# The area of Ghana is 238533.00 km2
# The area of Gibraltar is 6.00 km2
# The area of Greece is 131626.00 km2
# The area of Greenland is 2166090.00 km2
# The area of Grenada is 344.00 km2
# The area of Guadeloupe is 1705.00 km2
# The area of Guam is 549.00 km2
# The area of Guatemala is 108889.00 km2
# The area of Guinea is 245857.00 km2
# The area of Guinea-Bissau is 36125.00 km2
# The area of Guyana is 214969.00 km2
# The area of Haiti is 27750.00 km2
# The area of Heard Island and McDonald Islands is 359.00 km2
# The area of Holy See (Vatican City State) is 0.40 km2
# The area of Honduras is 112088.00 km2
# The area of Hong Kong is 1075.00 km2
# The area of Hungary is 93030.00 km2
# The area of Iceland is 103000.00 km2
# The area of India is 3287263.00 km2
# The area of Indonesia is 1904569.00 km2
# The area of Iran is 1648195.00 km2
# The area of Iraq is 438317.00 km2
# The area of Ireland is 70273.00 km2
# The area of Israel is 21056.00 km2
# The area of Italy is 301316.00 km2
# The area of Jamaica is 10990.00 km2
# The area of Japan is 377829.00 km2
# The area of Jordan is 88946.00 km2
# The area of Kazakstan is 2724900.00 km2
# The area of Kenya is 580367.00 km2
# The area of Kiribati is 726.00 km2
# The area of Kuwait is 17818.00 km2
# The area of Kyrgyzstan is 199900.00 km2
# The area of Laos is 236800.00 km2
# The area of Latvia is 64589.00 km2
# The area of Lebanon is 10400.00 km2
# The area of Lesotho is 30355.00 km2
# The area of Liberia is 111369.00 km2
# The area of Libyan Arab Jamahiriya is 1759540.00 km2
# The area of Liechtenstein is 160.00 km2
# The area of Lithuania is 65301.00 km2
# The area of Luxembourg is 2586.00 km2
# The area of Macao is 18.00 km2
# The area of Macedonia is 25713.00 km2
# The area of Madagascar is 587041.00 km2
# The area of Malawi is 118484.00 km2
# The area of Malaysia is 329758.00 km2
# The area of Maldives is 298.00 km2
# The area of Mali is 1240192.00 km2
# The area of Malta is 316.00 km2
# The area of Marshall Islands is 181.00 km2
# The area of Martinique is 1102.00 km2
# The area of Mauritania is 1025520.00 km2
# The area of Mauritius is 2040.00 km2
# The area of Mayotte is 373.00 km2
# The area of Mexico is 1958201.00 km2
# The area of Moldova is 33851.00 km2
# The area of Monaco is 1.50 km2
# The area of Mongolia is 1566500.00 km2
# The area of Montserrat is 102.00 km2
# The area of Morocco is 446550.00 km2
# The area of Mozambique is 801590.00 km2
# The area of Myanmar is 676578.00 km2
# The area of Namibia is 824292.00 km2
# The area of Nauru is 21.00 km2
# The area of Nepal is 147181.00 km2
# The area of Netherlands is 41526.00 km2
# The area of Netherlands Antilles is 800.00 km2
# The area of New Caledonia is 18575.00 km2
# The area of New Zealand is 270534.00 km2
# The area of Nicaragua is 130000.00 km2
# The area of Niger is 1267000.00 km2
# The area of Nigeria is 923768.00 km2
# The area of Niue is 260.00 km2
# The area of Norfolk Island is 36.00 km2
# The area of North Korea is 120538.00 km2
# The area of Northern Mariana Islands is 464.00 km2
# The area of Norway is 323877.00 km2
# The area of Oman is 309500.00 km2
# The area of Pakistan is 796095.00 km2
# The area of Palau is 459.00 km2
# The area of Palestine is 6257.00 km2
# The area of Panama is 75517.00 km2
# The area of Papua New Guinea is 462840.00 km2
# The area of Paraguay is 406752.00 km2
# The area of Peru is 1285216.00 km2
# The area of Philippines is 300000.00 km2
# The area of Pitcairn is 49.00 km2
# The area of Poland is 323250.00 km2
# The area of Portugal is 91982.00 km2
# The area of Puerto Rico is 8875.00 km2
# The area of Qatar is 11000.00 km2
# The area of Réunion is 2510.00 km2
# The area of Romania is 238391.00 km2
# The area of Russian Federation is 17075400.00 km2
# The area of Rwanda is 26338.00 km2
# The area of Saint Helena is 314.00 km2
# The area of Saint Kitts and Nevis is 261.00 km2
# The area of Saint Lucia is 622.00 km2
# The area of Saint Pierre and Miquelon is 242.00 km2
# The area of Saint Vincent and the Grenadines is 388.00 km2
# The area of Samoa is 2831.00 km2
# The area of San Marino is 61.00 km2
# The area of Sao Tome and Principe is 964.00 km2
# The area of Saudi Arabia is 2149690.00 km2
# The area of Senegal is 196722.00 km2
# The area of Seychelles is 455.00 km2
# The area of Sierra Leone is 71740.00 km2
# The area of Singapore is 618.00 km2
# The area of Slovakia is 49012.00 km2
# The area of Slovenia is 20256.00 km2
# The area of Solomon Islands is 28896.00 km2
# The area of Somalia is 637657.00 km2
# The area of South Africa is 1221037.00 km2
# The area of South Georgia and the South Sandwich Islands is 3903.00 km2
# The area of South Korea is 99434.00 km2
# The area of Spain is 505992.00 km2
# The area of Sri Lanka is 65610.00 km2
# The area of Sudan is 2505813.00 km2
# The area of Suriname is 163265.00 km2
# The area of Svalbard and Jan Mayen is 62422.00 km2
# The area of Swaziland is 17364.00 km2
# The area of Sweden is 449964.00 km2
# The area of Switzerland is 41284.00 km2
# The area of Syria is 185180.00 km2
# The area of Taiwan is 36188.00 km2
# The area of Tajikistan is 143100.00 km2
# The area of Tanzania is 883749.00 km2
# The area of Thailand is 513115.00 km2
# The area of The Democratic Republic of the Congo is 2344858.00 km2
# The area of Togo is 56785.00 km2
# The area of Tokelau is 12.00 km2
# The area of Tonga is 650.00 km2
# The area of Trinidad and Tobago is 5130.00 km2
# The area of Tunisia is 163610.00 km2
# The area of Turkey is 774815.00 km2
# The area of Turkmenistan is 488100.00 km2
# The area of Turks and Caicos Islands is 430.00 km2
# The area of Tuvalu is 26.00 km2
# The area of Uganda is 241038.00 km2
# The area of Ukraine is 603700.00 km2
# The area of United Arab Emirates is 83600.00 km2
# The area of United Kingdom is 242900.00 km2
# The area of United States is 9363520.00 km2
# The area of United States Minor Outlying Islands is 16.00 km2
# The area of Uruguay is 175016.00 km2
# The area of Uzbekistan is 447400.00 km2
# The area of Vanuatu is 12189.00 km2
# The area of Venezuela is 912050.00 km2
# The area of Vietnam is 331689.00 km2
# The area of Virgin Islands, British is 151.00 km2
# The area of Virgin Islands, U.S. is 347.00 km2
# The area of Wallis and Futuna is 200.00 km2
# The area of Western Sahara is 266000.00 km2
# The area of Yemen is 527968.00 km2
# The area of Yugoslavia is 102173.00 km2
# The area of Zambia is 752618.00 km2
# The area of Zimbabwe is 390757.00 km2

# %%
import csv  

header = ['name', 'area', 'country_code2', 'country_code3']
data = ['Afghanistan', 652090, 'AF', 'AFG']

with open('countries.csv', 'w', encoding='UTF8') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write the data
    writer.writerow(data)

# %%
import csv

header = ['name', 'area', 'country_code2', 'country_code3']
data = ['Afghanistan', 652090, 'AF', 'AFG']


with open('countries.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write the data
    writer.writerow(data)

# %%
import csv

header = ['name', 'area', 'country_code2', 'country_code3']
data = [
    ['Albania', 28748, 'AL', 'ALB'],
    ['Algeria', 2381741, 'DZ', 'DZA'],
    ['American Samoa', 199, 'AS', 'ASM'],
    ['Andorra', 468, 'AD', 'AND'],
    ['Angola', 1246700, 'AO', 'AGO']
]

with open('countries.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write multiple rows
    writer.writerows(data)

# %%
import os

try:
    os.rename('readme.txt', 'notes.txt')
except FileNotFoundError as e:
    print(e)
except FileExistsError as e:
    print(e)

# %% [markdown]
# ## Section 13

# %%
import os


cwd = os.getcwd()
print(cwd)
# Out:
# c:\Users\manis\Downloads

# %%
import os

fp = os.path.join('temp', 'python')
print(fp)  # temp\python (on Windows)

pc = os.path.split(fp)
print(pc)  # ('temp', 'python')
# Out:
# temp\python
# ('temp', 'python')

# %%
import os

dir = os.path.join("C:\\", "temp")
print(dir)

if os.path.exists(dir) or os.path.isdir(dir):
    print(f'The {dir} is a directory')
# Out:
# C:\temp

# %%
import os

path = "c:\\temp"
for root, dirs, files in os.walk(path):
    print("{0} has {1} files".format(root, len(files)))

# %%
import os


path = 'C:\\Users\\manis\\'

html_files = []

for dirpath, dirnames, filenames in os.walk(path):
    for filename in filenames:
        if filename.endswith('.html'):
            html_files.append(os.path.join(dirpath, filename))

for html_file in html_files:
    print(html_file)

# %% [markdown]
# ## Section 14

# %%
name = 'John'
s = f'Hello, {name}!'
print(s)
# Out:
# Hello, John!

# %%
first_name = 'John'
last_name = 'Doe'
s = F'Hello, {first_name} {last_name}!'
print(s)
# Out:
# Hello, John Doe!

# %%
name = 'John'
website = 'PythonTutorial.net'

message = (
    f'Hello {name}. '
    f"You're learning Python at {website}." 
)

print(message)
# Out:
# Hello John. You're learning Python at PythonTutorial.net.

# %%
name = 'John'
website = 'PythonTutorial.net'

message = f"""Hello {name}.
You're learning Python at {website}."""

print(message)
# Out:
# Hello John.
# You're learning Python at PythonTutorial.net.

# %%
s = f'{{1+2}}'
print(s)
# Out:
# {1+2}

# %%
def inc(numbers, value):
    numbers[0] += value
    return numbers[0]

numbers = [0]

s = f'{inc(numbers,1)},{inc(numbers,2)}'
print(s)
# Out:
# 1,3

# %%
number = 400000000000
s = f'{number: ,}'  # also can use _
print(s)  # 400,000,000,000
# Out:
#  400,000,000,000

# %%
number = 0.1259
s = f'{number: .2%}'
print(s)  # 12.59%

s = f'{number: .1%}'
print(s)  # 12.5%
# Out:
#  12.59%
#  12.6%

# %%
s = 'lang\tver\nPython\t3'
print(s)
# Out:
# lang	ver
# Python	3

# %%
s1 = r'lang\tver\nPython\t3'
s2 = 'lang\\tver\\nPython\\t3'

print(s1 == s2) # True
# Out:
# True

# %%
dir_path = 'c:\\Users\\manis\\'

# %%
s = '\n'
raw_string = repr(s)

print(raw_string)
# Out:
# '\n'

# %%
print('Hello,\n World')
# Out:
# Hello,
#  World

# %%
colors = ['red','green','blue']
rgb = '\n'.join(colors)
s = f"The RGB colors are:\n{rgb}"
print(s)
# Out:
# The RGB colors are:
# red
# green
# blue

# %%
s = r'\n'
print(s)
# Out:
# \n

# %% [markdown]
# ### Section 15

# %%
pip --version
# Out:
# pip 24.2 from c:\Users\manis\anaconda3\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                           Version            Editable project location
# --------------------------------- ------------------ ----------------------------------------------------------------------------------------
# absl-py                           2.1.0
# accelerate                        1.5.1
# ace_tools                         0.0
# addict                            2.4.0
# aext-assistant                    4.1.0
# aext-assistant-server             4.1.0
# aext-core                         4.1.0
# aext-core-server                  4.1.0
# aext-panels                       4.1.0
# aext-panels-server                4.1.0
# aext-project-filebrowser-server   4.1.0
# aext-share-notebook               4.1.0
# aext-share-notebook-server        4.1.0
# aext-shared                       4.1.0
# aext-toolbox                      4.1.0
# aiobotocore                       2.12.3
# aiofiles                          24.1.0
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# alembic                           1.13.3
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.4.1
# anaconda-client                   1.13.0
# anaconda-cloud-auth               0.7.2
# anaconda-navigator                2.6.3
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argcomplete                       3.5.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# asgiref                           3.8.1
# astroid                           2.14.2
# astropy                           6.1.3
# astropy-iers-data                 0.2024.9.2.0.33.23
# asttokens                         2.0.5
# astunparse                        1.6.3
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attr                              0.3.1
# attrs                             25.3.0
# audioread                         3.0.1
# Automat                           20.2.0
# autopep8                          2.0.4
# azure-core                        1.32.0
# azure-storage-blob                12.24.1
# Babel                             2.11.0
# backoff                           2.2.1
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.8.0
# bleach                            5.0.1
# blinker                           1.6.2
# bokeh                             3.6.0
# boltons                           23.0.0
# boto                              2.49.0
# boto3                             1.36.22
# botocore                          1.36.22
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# cachetools                        5.3.3
# cairocffi                         1.7.1
# CairoSVG                          2.7.1
# certifi                           2024.12.14
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.3.2
# click                             8.1.7
# cloudpickle                       3.0.0
# colorama                          0.4.6
# colorcet                          3.1.0
# coloredlogs                       15.0.1
# comm                              0.2.1
# conda                             24.11.3
# conda-build                       24.9.0
# conda-content-trust               0.2.0
# conda_index                       0.5.0
# conda-libmamba-solver             24.9.0
# conda-pack                        0.7.1
# conda-package-handling            2.3.0
# conda_package_streaming           0.10.0
# conda-repo-cli                    1.0.114
# conda-token                       0.5.0+1.g2209e04
# constantly                        23.10.4
# contourpy                         1.2.0
# cookiecutter                      2.6.0
# cryptography                      43.0.0
# cssselect                         1.2.0
# cssselect2                        0.7.0
# cycler                            0.11.0
# cytoolz                           0.12.2
# dask                              2024.8.2
# dask-expr                         1.1.13
# dataclasses-json                  0.6.7
# datamodel-code-generator          0.26.1
# datashader                        0.16.3
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# Deprecated                        1.2.18
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2024.8.2
# distro                            1.9.0
# Django                            5.1.6
# django-annoying                   0.10.6
# django-cors-headers               3.6.0
# django-csp                        3.7
# django-debug-toolbar              3.2.1
# django-environ                    0.10.0
# django-extensions                 3.2.3
# django-filter                     24.3
# django-migration-linter           5.1.0
# django-model-utils                4.1.1
# django-ranged-fileresponse        0.1.2
# django-rq                         2.10.3
# django-storages                   1.12.3
# django-user-agents                0.4.0
# djangorestframework               3.15.2
# dnspython                         2.7.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# drf-dynamic-fields                0.3.0
# drf-flex-fields                   0.9.5
# drf-generators                    0.3.0
# editdistance                      0.8.1
# email_validator                   2.2.0
# emoji                             2.14.1
# et-xmlfile                        1.1.0
# eval_type_backport                0.2.2
# executing                         0.8.3
# expiringdict                      1.2.2
# faiss-cpu                         1.10.0
# Faker                             36.1.1
# fastjsonschema                    2.16.2
# fica                              0.4.1
# filelock                          3.13.1
# filetype                          1.2.0
# flake8                            7.0.0
# Flask                             3.0.3
# flatbuffers                       25.1.24
# fonttools                         4.51.0
# fqdn                              1.5.1
# frozendict                        2.4.2
# frozenlist                        1.4.0
# fsspec                            2024.6.1
# fuzzywuzzy                        0.18.0
# gast                              0.6.0
# gensim                            4.3.3
# genson                            1.3.0
# gitdb                             4.0.7
# GitPython                         3.1.43
# google-api-core                   2.24.1
# google-auth                       2.38.0
# google-cloud-appengine-logging    1.6.0
# google-cloud-audit-log            0.3.0
# google-cloud-core                 2.4.1
# google-cloud-logging              3.11.4
# google-cloud-storage              2.19.0
# google-crc32c                     1.6.0
# google-pasta                      0.2.0
# google-resumable-media            2.7.2
# googleapis-common-protos          1.67.0
# greenlet                          3.2.4
# grpc-google-iam-v1                0.14.0
# grpcio                            1.70.0
# grpcio-status                     1.70.0
# h11                               0.14.0
# h5py                              3.11.0
# HeapDict                          1.0.1
# holoviews                         1.19.1
# html5lib                          1.1
# httpcore                          1.0.2
# httpx                             0.27.0
# httpx-sse                         0.4.0
# huggingface-hub                   0.29.3
# humanfriendly                     10.0
# humansignal-drf-yasg              1.21.10.post1
# hvplot                            0.11.0
# hyperlink                         21.0.0
# idna                              3.7
# idx2numpy                         1.2.3
# ijson                             3.3.0
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# importlib-metadata                7.0.1
# incremental                       22.10.0
# inflect                           5.6.2
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            2.0.7
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipylab                            1.1.0
# ipython                           8.27.0
# ipython-genutils                  0.2.0
# ipywidgets                        8.1.7
# isodate                           0.7.2
# isoduration                       20.11.0
# isort                             5.13.2
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jedi                              0.19.1
# jellyfish                         1.0.1
# Jinja2                            3.1.4
# jiter                             0.8.2
# jmespath                          1.0.1
# joblib                            1.4.2
# jsf                               0.11.2
# json5                             0.9.6
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.23.0
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.10.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.14.1
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.2.5
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.27.3
# jupyterlab_widgets                3.0.15
# jupytext                          1.17.3
# keras                             3.8.0
# keras-tqdm                        2.0.1
# keyring                           24.3.1
# kiwisolver                        1.4.4
# label-studio                      1.16.0
# label-studio-sdk                  1.0.10
# langchain                         0.3.20
# langchain-community               0.3.19
# langchain-core                    0.3.44
# langchain-ollama                  0.2.2
# langchain-text-splitters          0.3.6
# langdetect                        1.0.9
# langsmith                         0.2.11
# launchdarkly-server-sdk           8.2.1
# lazy_loader                       0.4
# lazy-object-proxy                 1.10.0
# lckr_jupyterlab_variableinspector 3.1.0
# Levenshtein                       0.26.1
# libarchive-c                      5.1
# libclang                          18.1.1
# libmagic                          1.0
# libmambapy                        1.5.8
# librosa                           0.10.2.post1
# linkify-it-py                     2.0.0
# lizard                            1.17.20
# llvmlite                          0.43.0
# lmdb                              1.4.1
# locket                            1.0.0
# lockfile                          0.12.2
# lxml                              5.2.1
# lxml_html_clean                   0.4.1
# lz4                               4.3.2
# Mako                              1.2.3
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# marshmallow                       3.26.1
# matplotlib                        3.9.2
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.1.2
# mistune                           2.0.4
# mkl_fft                           1.3.10
# mkl_random                        1.2.7
# mkl-service                       2.4.0
# ml_dtypes                         0.5.1
# mltu                              1.2.5
# more-itertools                    10.3.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# mypy                              1.11.2
# mypy-extensions                   1.0.0
# namex                             0.0.8
# navigator-updater                 0.5.1
# nb_conda_kernels                  2.5.2
# nbclient                          0.8.0
# nbconvert                         7.16.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# ninja                             1.11.1.3
# nltk                              3.9.1
# notebook                          7.2.2
# notebook_shim                     0.2.3
# numba                             0.60.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.7.0
# object_detection                  0.1
# object_detection                  0.1
# olefile                           0.47
# ollama                            0.4.6
# onnx                              1.17.0
# onnxruntime                       1.21.0
# openai                            1.75.0
# opencv-python                     4.11.0.86
# openpyxl                          3.1.5
# opentelemetry-api                 1.30.0
# opt_einsum                        3.4.0
# optree                            0.14.0
# ordered-set                       4.0.2
# orjson                            3.10.15
# otter-grader                      6.1.4
# outcome                           1.3.0.post0
# overrides                         7.4.0
# packaging                         24.1
# pandas                            2.2.3
# pandocfilters                     1.5.0
# panel                             1.5.2
# param                             2.1.1
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# path                              17.1.0
# pathspec                          0.10.3
# patsy                             0.5.6
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            10.4.0
# pip                               24.2
# pkce                              1.0.3
# pkginfo                           1.10.0
# platformdirs                      3.10.0
# playwright                        1.55.0
# plotly                            5.24.1
# pluggy                            1.0.0
# ply                               3.11
# pooch                             1.8.2
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# proto-plus                        1.26.0
# protobuf                          3.20.3
# psutil                            5.9.0
# psycopg2-binary                   2.9.10
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           16.1.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pybind11                          2.13.6
# pyboxen                           1.3.0
# pyclipper                         1.3.0.post6
# pycodestyle                       2.11.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.3
# pydantic                          2.10.5
# pydantic_core                     2.27.2
# pydantic-settings                 2.6.1
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# PyDriller                         2.7
# pyee                              13.0.0
# pyerfa                            2.0.1.4
# pyflakes                          3.2.0
# Pygments                          2.15.1
# PyJWT                             2.8.0
# pylint                            2.16.2
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.1.0
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# pyparsing                         2.4.7
# pypdf                             5.3.1
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# pyreadline3                       3.5.4
# pyRFC3339                         2.0.1
# PySocks                           1.7.1
# pytest                            7.4.4
# python-bidi                       0.6.3
# python-dateutil                   2.9.0.post0
# python-dotenv                     0.21.0
# python-iso639                     2025.2.18
# python-json-logger                2.0.4
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.10.0
# python-magic                      0.4.27
# python-magic-bin                  0.4.14
# python-on-whales                  0.78.0
# python-oxmsg                      0.0.2
# python-slugify                    5.0.2
# pytoolconfig                      1.2.6
# pytz                              2022.7.1
# pyviz_comms                       3.0.2
# PyWavelets                        1.7.0
# pywin32                           305.1
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.10
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.2.3
# qqdm                              0.0.7
# qstylizer                         0.2.2
# QtAwesome                         1.3.1
# qtconsole                         5.5.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# RapidFuzz                         3.12.1
# readchar                          4.0.5
# redis                             5.2.1
# referencing                       0.30.2
# regex                             2024.9.11
# requests                          2.32.3
# requests-file                     1.5.1
# requests-mock                     1.12.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.7.1
# rope                              1.12.0
# rpds-py                           0.10.6
# rq                                1.16.2
# rsa                               4.9
# rstr                              3.2.2
# Rtree                             1.0.1
# ruamel.yaml                       0.18.6
# ruamel.yaml.clib                  0.2.8
# ruamel-yaml-conda                 0.17.21
# rules                             3.4
# s3fs                              2024.6.1
# s3transfer                        0.11.2
# sacrebleu                         2.2.0
# sacrebleu                         2.2.0
# safetensors                       0.5.3
# scikit-image                      0.24.0
# scikit-learn                      1.5.1
# scipy                             1.13.1
# Scrapy                            2.11.1
# seaborn                           0.13.2
# selenium                          4.31.0
# semver                            3.0.2
# Send2Trash                        1.8.2
# sentence-transformers             3.4.1
# sentry-sdk                        2.18.0
# service-identity                  18.1.0
# setuptools                        75.8.0
# shapely                           2.0.7
# shellingham                       1.5.0
# sip                               6.7.12
# six                               1.16.0
# slim                              0.1                C:\Users\manis\Downloads\TFODCourse-main\TFODCourse-main\Tensorflow\models\research\slim
# smart-open                        7.1.0
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soundfile                         0.13.1
# soupsieve                         2.5
# soxr                              0.5.0.post1
# Sphinx                            7.3.7
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.10
# spyder                            5.5.1
# spyder-kernels                    2.5.0
# SQLAlchemy                        2.0.34
# sqlparse                          0.5.3
# stack-data                        0.2.0
# statsmodels                       0.14.2
# streamlit                         1.37.1
# sympy                             1.13.1
# tables                            3.10.1
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          8.2.3
# tensorboard                       2.19.0
# tensorboard-data-server           0.7.2
# tensorflow                        2.19.0
# tensorflow_intel                  2.18.0
# termcolor                         2.5.0
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.2.1
# tf_keras                          2.19.0
# tf-slim                           1.1.0
# tf2onnx                           1.16.1
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tiktoken                          0.9.0
# tinycss2                          1.2.1
# tldextract                        5.1.3
# tokenizers                        0.21.0
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.11.1
# toolz                             0.12.0
# torch                             2.6.0
# tornado                           6.4.1
# tqdm                              4.66.5
# traitlets                         5.14.3
# transformers                      4.49.0
# trio                              0.29.0
# trio-websocket                    0.12.2
# truststore                        0.8.0
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typer                             0.9.0
# types-pytz                        2025.1.0.20250204
# typing_extensions                 4.12.2
# typing-inspect                    0.9.0
# typing-inspection                 0.4.0
# tzdata                            2023.3
# ua-parser                         1.0.1
# ua-parser-builtins                0.18.0.post1
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# unicodedata2                      15.1.0
# Unidecode                         1.3.8
# unstructured                      0.17.0
# unstructured-client               0.31.1
# uri-template                      1.3.0
# uritemplate                       4.1.1
# urllib3                           1.26.20
# user-agents                       2.2.0
# w3lib                             2.1.2
# watchdog                          4.0.1
# wcwidth                           0.2.5
# webcolors                         24.11.1
# webdriver-manager                 4.0.2
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# wget                              3.2
# whatthepatch                      1.0.2
# wheel                             0.40.0
# widgetsnbextension                4.0.14
# win-inet-pton                     1.1.0
# wrapt                             1.17.3
# wsproto                           1.2.0
# xarray                            2023.6.0
# xlwings                           0.32.1
# xmljson                           0.2.1
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.11.0
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.23.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ympy (c:\Users\manis\anaconda3\Lib\site-packages)
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\object_detection-0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\pyparsing-2.4.7-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\sacrebleu-2.2.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ympy (c:\Users\manis\anaconda3\Lib\site-packages)
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\object_detection-0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\pyparsing-2.4.7-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\sacrebleu-2.2.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import requests

response = requests.get('https://www.google.com')
if response.status_code == 200:
    print(response.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world's information, including webpages, images, videos and more. Google has many special features to help you find exactly what you're looking for." name="description"><meta content="noodp, " name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="pnmVSGeA-bYf2Q_u6nH4Mg">(function(){var _g={kEI:'flzKaJ31IO2GptQP2q3DsAU',kEXPI:'0,202854,2,83,3946973,90133,14111,34680,390923,238458,51586,5230281,6004084,30819959,25228681,123988,14280,14115,4558,18355,34213,5381,2659,3435,3319,23879,7041,2097,4600,328,6225,54190,9265,710,15048,49,8162,3286,4134,30380,28333,22957,19931,6017,5308,352,18880,5870,1898,5809,7,5774,24960,1,3,2647,7268,9256,6251,28,7,1,1293,2126,2863,1,5970,4650,2360,9747,5683,3604,17765,7,1,2729,3477,8603,3189,1282,14882,438,550,5006,1016,1,8907,727,1033,655,1638,3791,352,9743,2646,98,5,4,1,320,844,4256,670,2388,1722,805,5799,2303,862,4,4165,9592,4138,77,210,1281,407,183,1,2,1379,32,104,3044,311,198,859,2843,2110,2,1347,5,2,681,127,3371,5,2320,2,7,539,4,5,2,2523,109,1930,17,1639,82,1205,158,4,738,17,1595,1871,1,2,873,2,23,2207,569,3925,614,3008,24,771,3665,392,1,4,607,1078,92,2,3392,548,126,110,5,2516,3121,1134,2224,516,21,89,7,645,6,5,241,1044,1349,312,2,548,746,613,5,474,1,1,1,506,2253,5,7,1138,2,540,22,72,1,193,1594,2517,120,506,140,318,210,48,788,125,117,2,1,1,4,10,1039,253,288,275,1362,1367,491,263,49,306,29,3,2,2,2,1036,363,805,1,2,11,2,464,377,1,8,1,1162,315,816,1093,200,9,27,8,1487,2,3,2,2,2,329,1228,360,4,325,320,2,119,2,602,984,39,4,632,2,189,1,333,5,8,2,151,595,81,366,675,1143,170,103,2,112,72,547,195,97,11,4,2067,1804,54,1,1,2,232,993,209,234,2,159,9,114,566,159,423,331,520,310,46,83,11,545,653,234,3,3,825,2,5,509,41,77,5,415,3,9,1,128,328,365,1,107,162,1,11,1,131,346,153,205,238,453,881,815,45,399,124,756,706,304,1103,250,14,14,87,740,939,289,115,72,10,132,2,95,58,2,206,137,2,267,90,940,5,948,208,1,2,802,75,647,172,579,21131586,1717,7635,5,2992,4,2700,260,3,8491,2,1562,3,997,1445,3,8640,158,1033,655,1164,118,698,499,1461,355,150,10135872',kBL:'JMwC',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='en';})();(function(){
# var g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy={};function e(a,b,c){if(a)var d=a.id;else{do d=Math.random();while(c[d])}c[d]=[a,b]}var f;(f=google).x||(f.x=function(a,b){e(a,b,google.y)});var g;(g=google).sx||(g.sx=function(a,b){e(a,b,google.sy)});google.lm=[];var h;(h=google).plm||(h.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var k;(k=google).load||(k.load=function(a,b,c){google.lq.push([[a],b,c])});var l;(l=google).loadAll||(l.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var m;(m=google).lx||(m.lx=function(){});var n=[],p;(p=google).fce||(p.fce=function(a,b,c,d){n.push([a,b,c,d])});google.qce=n;google.adl=[];}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px sans-serif}.gsfs{font:17px sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#1f1f1f}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#ecedee;border:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#1f1f1f;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style><script nonce="pnmVSGeA-bYf2Q_u6nH4Mg">(function(){window.google.erd={jsr:1,bv:2290,de:true,dpf:'PcL08rzbTPR1-DRy89inppPpgW7eyyQ2AmGUR52MG_A'};
# var g=this||self;var k,l=(k=g.mei)!=null?k:1,m,p=(m=g.diel)!=null?m:0,q,r=(q=g.sdo)!=null?q:!0,t=0,u,w=google.erd,x=w.jsr;google.ml=function(a,b,d,n,e){e=e===void 0?2:e;b&&(u=a&&a.message);d===void 0&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d,!0),null;b=d;if(x<0){window.console&&console.error(a,b);if(x===-2)throw a;b=!1}else b=!a||!a.message||a.message==="Error loading script"||t>=l&&!n?!1:!0;if(!b)return null;t++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(w.jsr)+
# "&bver="+b(w.bv);w.dpf&&(c+="&dpf="+b(w.dpf));var f=a.lineNumber;f!==void 0&&(c+="&line="+f);var h=a.fileName;h&&(h.indexOf("-extension:/")>0&&(e=3),c+="&script="+b(h),f&&h===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));google.ple&&google.ple===1&&(e=2);c+="&jsel="+e;for(var v in d)c+="&",c+=b(v),c+="=",c+=b(d[v]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");c.length>=12288&&(c=c.substring(0,12288));a=c;n||google.log(0,"",a);return a};window.onerror=function(a,b,d,n,e){u!==a&&(a=e instanceof Error?e:Error(a),d===void 0||"lineNumber"in a||(a.lineNumber=d),b===void 0||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,a.name==="SyntaxError"||a.message.substring(0,11)==="SyntaxError"||a.message.indexOf("Script error")!==-1?3:p));u=null;r&&t>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="pnmVSGeA-bYf2Q_u6nH4Mg">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id=gbar><nobr><b class=gb1>Search</b> <a class=gb1 href="https://www.google.com/imghp?hl=en&tab=wi">Images</a> <a class=gb1 href="https://maps.google.com/maps?hl=en&tab=wl">Maps</a> <a class=gb1 href="https://play.google.com/?hl=en&tab=w8">Play</a> <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/?tab=wn">News</a> <a class=gb1 href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">Drive</a> <a class=gb1 style="text-decoration:none" href="https://www.google.com/intl/en/about/products?tab=wh"><u>More</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href="http://www.google.com/history/optout?hl=en" class=gb4>Web History</a> | <a  href="/preferences?hl=en" class=gb4>Settings</a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=https://www.google.com/&ec=GAZAAQ" class=gb4>Sign in</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div></div><center><br clear="all" id="lgpd"><div id="XjhHGf"><img alt="Google" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="en" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><input class="lst" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#1f1f1f" autocomplete="off" value="" title="Google Search" maxlength="2048" name="q" size="57"></div><br style="line-height:0"><span class="ds"><span class="lsbb"><input class="lsb" value="Google Search" name="btnG" type="submit"></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_flzKaJ31IO2GptQP2q3DsAU_1" value="I'm Feeling Lucky" name="btnI" type="submit"><script nonce="pnmVSGeA-bYf2Q_u6nH4Mg">(function(){var id='tsuid_flzKaJ31IO2GptQP2q3DsAU_1';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input value="AOw8s4IAAAAAaMpqjqwzeNVND6j_TEF-wmvqzgRiTiLr" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap="" width="25%"><a href="/advanced_search?hl=en&amp;authuser=0">Advanced search</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="pnmVSGeA-bYf2Q_u6nH4Mg">(function(){var a,b="1";if(document&&document.getElementById)if(typeof XMLHttpRequest!="undefined")b="2";else if(typeof ActiveXObject!="undefined"){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if(a=="2"&&location.search.indexOf("&gbv=2")==-1){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div style="font-size:83%;min-height:3.5em"><br></div><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQANb"><a href="/intl/en/ads/">Advertising</a><a href="/services/">Business Solutions</a><a href="/intl/en/about.html">About Google</a></div></div><p style="font-size:8pt;color:#636363">&copy; 2025 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="pnmVSGeA-bYf2Q_u6nH4Mg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=window.google&&window.google.kOPI||null;k&&(h+="&opi="+k);f.call(e,"","",g+h)};}).call(this);})();(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.Aqh0idXVnKw.es5.O/ck\x3dxjs.hp.KtCQmqE9xFI.L.X.O/am\x3dAAIAAAAAAAAgAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAIAAABBQCAAAAAAAAAAAAAAAAACAAAAwKAE4AAAAIAAQIAAAAAAgAAAGAAAAAAACQAAAgABAAAQ3xEAAAAIxCIAAACAFw/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF_E56pEa1UNmcqyWodDjM7yb-GnQ',basecss:'/xjs/_/ss/k\x3dxjs.hp.KtCQmqE9xFI.L.X.O/am\x3dAAIAAAAAAAAgAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAIAAABBACAAAAAAAAAAAAAAAAACAAAAwKAAAAAAAIAAQIAAAAAAgAAAGAAAAAAACQAAAgABAAAAAAAAAAAABA/rs\x3dACT90oHXU_vEY7m8RHDvbkn0dROWigeT7g',basejs:'/xjs/_/js/k\x3dxjs.hp.en.Aqh0idXVnKw.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAABQAAAAAAAAAAAAAAAAAACAAAAAAAE4AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQ3xEAAAAIwCIAAACAFw/dg\x3d0/rs\x3dACT90oGyGp4Z3pcG6zxv9a2mgMrE1Q0BCA',excm:[]};})();(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.Aqh0idXVnKw.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAABQAAAAAAAAAAAAAAAAAACAAAAAAAE4AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQ3xEAAAAIwCIAAACAFw/d\x3d1/ed\x3d1/dg\x3d3/rs\x3dACT90oGyGp4Z3pcG6zxv9a2mgMrE1Q0BCA/m\x3dsb_he,d';var st=1;var amd=1000;var mmd=0;var pop=true;var povp=false;var fp='';
# var e=this||self;function f(){var a=google.ia&&google.ia.r.B2Jtyd;return a&&[1,5,6].indexOf(a.m)>=0&&a.cbfd&&a.cbvi?a:void 0};function g(a){var b=document.createElement("link");b.as="script";b.href=a;b.rel="preload";document.body.appendChild(b)}function k(){var a=[u];google.dp||(a.forEach(g),google.dp=!0)};google.ps=google.ps||[];function l(){var a=u,b=function(){};google.lx=google.stvsc?b:function(){m(a);google.lx=b};google.bx||google.lx()}function n(a,b){b&&(a.src=b);fp&&google.caft&&google.caft(function(){a.fetchPriority=fp});var h=a.onload;a.onload=function(d){h&&h(d);google.ps=google.ps.filter(function(c){return a!==c})};google.ps.push(a);document.body.appendChild(a)}google.as=n;function m(a){google.tick&&google.tick("load","xjsls");var b=document.createElement("script");b.onerror=function(){google.ple=1};b.onload=function(){google.ple=0};google.xjsus=void 0;n(b,a);google.aple=-1;google.dp=!0};function p(){for(var a=document.getElementsByTagName("img"),b=0,h=a.length;b<h;b++){var d=a[b],c;if(c=d.hasAttribute("data-lzy_")&&Number(d.getAttribute("data-atf"))&1)c=d.getAttribute("jscontroller"),c=!((c==="UBXHI"||c==="R3fhkb"||c==="TSZEqd")&&d.hasAttribute("data-src"));if(c)return!0}return!1};var q,r,t,w,x,y,z,A,B;function C(){google.xjsu=u;e._F_jsUrl=u;x=function(){l()};q=!1;r=(st===1||st===3)&&!!google.caft&&!p();t=f();w=(st===2||st===3)&&!!t&&!p();y=pop;z=povp;A=y&&document.prerendering||z&&document.hidden;B=z?"visibilitychange":"prerenderingchange"}function D(){q||r||w||A||(x(),q=!0)}
# setTimeout(function(){google.tick&&google.tick("load","xjspls");C();if(r||w||A){if(r){var a=function(){r=!1;D()};google.caft(a);setTimeout(a,amd)}w&&(a=function(){w=!1;D()},t.cbvi.push(a),setTimeout(a,mmd));if(A){var b=function(){(z?document.hidden:document.prerendering)||(A=!1,D(),document.removeEventListener(B,b))};document.addEventListener(B,b,{passive:!0})}q||k()}else x()},0);})();window._ = window._ || {};window._DumpException = _._DumpException = function(e){throw e;};window._s = window._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {};_qs._DumpException = _._DumpException;(function(){var t=[512,0,512,0,0,0,0,128,512,25265152,2,8388608,0,2048,168559552,1488897,32772,513,526400,1536,150994944,537657344,16,292804,67633152,139,96256];window._F_toggles = window._xjs_toggles = t;})();window._F_installCss = window._F_installCss || function(css){};(function(){google.jl={bfl:0,dw:false,eli:false,ine:false,ubm:false,uwp:true,vs:false};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Clear Search\x22,\x22dym\x22:\x22Did you mean:\x22,\x22lcky\x22:\x22I\\u0026#39;m Feeling Lucky\x22,\x22lml\x22:\x22Learn more\x22,\x22psrc\x22:\x22This search was removed from your \\u003Ca href\x3d\\\x22/history\\\x22\\u003EWeb History\\u003C/a\\u003E\x22,\x22psrl\x22:\x22Remove\x22,\x22sbit\x22:\x22Search by image\x22,\x22srch\x22:\x22Google Search\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22stok\x22:\x22mWBo-PXF7Lt8RGBPKaDhcnL_NSc\x22}}';google.pmc=JSON.parse(pmc);})();</script></body></html>

# %%
pip install pipenv
# Out:
# Collecting pipenv
#   Downloading pipenv-2025.0.4-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: certifi in c:\users\manis\anaconda3\lib\site-packages (from pipenv) (2024.12.14)
# Requirement already satisfied: packaging>=22 in c:\users\manis\anaconda3\lib\site-packages (from pipenv) (24.1)
# Requirement already satisfied: setuptools>=67 in c:\users\manis\anaconda3\lib\site-packages (from pipenv) (75.8.0)
# Collecting virtualenv>=20.24.2 (from pipenv)
#   Downloading virtualenv-20.34.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.24.2->pipenv)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\manis\anaconda3\lib\site-packages (from virtualenv>=20.24.2->pipenv) (3.13.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\manis\anaconda3\lib\site-packages (from virtualenv>=20.24.2->pipenv) (3.10.0)
# Downloading pipenv-2025.0.4-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 1.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/2.9 MB 1.0 MB/s eta 0:00:03
#    -------------- ------------------------- 1.0/2.9 MB 1.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.9 MB 1.1 MB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.9 MB 1.1 MB/s eta 0:00:02
#    --------------------- ------------------ 1.6/2.9 MB 1.0 MB/s eta 0:00:02
#    ------------------------- -------------- 1.8/2.9 MB 1.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 2.1/2.9 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 1.0 MB/s eta 0:00:00
# Downloading virtualenv-20.34.0-py3-none-any.whl (6.0 MB)
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.0 MB 1.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 0.8/6.0 MB 1.0 MB/s eta 0:00:05
#    ------- -------------------------------- 1.0/6.0 MB 1.1 MB/s eta 0:00:05
#    -------- ------------------------------- 1.3/6.0 MB 1.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.6/6.0 MB 1.0 MB/s eta 0:00:05
#    ------------ --------------------------- 1.8/6.0 MB 1.1 MB/s eta 0:00:04
#    ------------ --------------------------- 1.8/6.0 MB 1.1 MB/s eta 0:00:04
#    -------------- ------------------------- 2.1/6.0 MB 1.1 MB/s eta 0:00:04
#    --------------- ------------------------ 2.4/6.0 MB 1.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 2.6/6.0 MB 1.1 MB/s eta 0:00:04
#    ------------------- -------------------- 2.9/6.0 MB 1.1 MB/s eta 0:00:03
#    --------------------- ------------------ 3.1/6.0 MB 1.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.4/6.0 MB 1.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.4/6.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------ --------------- 3.7/6.0 MB 1.1 MB/s eta 0:00:03
#    -------------------------- ------------- 3.9/6.0 MB 1.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.2/6.0 MB 1.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.5/6.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 4.7/6.0 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 5.0/6.0 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.2/6.0 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.2/6.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 5.5/6.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 5.8/6.0 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.0/6.0 MB 1.1 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
# Installing collected packages: distlib, virtualenv, pipenv
# Successfully installed distlib-0.4.0 pipenv-2025.0.4 virtualenv-20.34.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ympy (c:\Users\manis\anaconda3\Lib\site-packages)
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\object_detection-0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\pyparsing-2.4.7-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\manis\anaconda3\lib\site-packages\sacrebleu-2.2.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ympy (c:\Users\manis\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (c:\Users\manis\anaconda3\Lib\site-packages)
